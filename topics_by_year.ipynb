# %% [markdown]
# Install and load libraries

# %%
# !pip install pyLDAvis
# !pip install spacy
! pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
import os
import platform
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta
# Out:
# Requirement already satisfied: pyLDAvis in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (3.3.1)
# Requirement already satisfied: numexpr in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (0.23.2)
# Requirement already satisfied: gensim in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (4.1.2)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (3.0.3)
# Requirement already satisfied: numpy>=1.20.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (1.21.4)
# Requirement already satisfied: funcy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (0.17.0)
# Requirement already satisfied: sklearn in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (59.6.0)
# Requirement already satisfied: pandas>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (1.5.4)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas>=1.2.0->pyLDAvis) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: smart-open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scikit-learn->pyLDAvis) (2.1.0)
# Requirement already satisfied: six>=1.5 in /Users/darynabilodid/Library/Python/3.8/lib/python/site-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.14.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from packaging->numexpr->pyLDAvis) (2.4.7)
# Requirement already satisfied: spacy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (3.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (2.26.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (3.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (59.6.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.9 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (8.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (0.7.5)
# Requirement already satisfied: pathy>=0.3.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: numpy>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (1.21.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jinja2->spacy) (2.0.1)
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 248 kB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from en-core-web-sm==2.2.0) (3.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.6.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.21.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.26.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (4.62.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.7.5)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (21.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.4.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.9 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (8.0.13)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from packaging>=20.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pathy>=0.3.5->spacy>=2.2.0->en-core-web-sm==2.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=2.2.0->en-core-web-sm==2.2.0) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jinja2->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.1)

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

import spacy, nltk, gensim, sklearn
import pyLDAvis.gensim_models
from spacy.lang.en import English

# %% [markdown]
# Load the dataset

# %%
PKL_PATH = 'data/pkl'
df = pd.read_pickle(os.path.join(PKL_PATH, "final_subset_flaired.pkl"))
df['date'] = pd.DatetimeIndex(df['date']) #  set the date variable 
df = df.drop(columns=['quoteID','qids', 'probas','urls','phase', 'flair_score', 'subset', 'id', 'givenName', 'familyName', 'unaccentedGivenName', 'honorificSuffix', 'unaccentedFamilyName','middleName', 'honorificPrefix','deathYear', 'birthYear', 'textblob_score'])
df.head(3)
# Out:
#    Unnamed: 0                                          quotation  \
# 0        1356  the bill that republicans tried to place in th...
# 1        1358  she is the leading candidate, whether it be re...
# 2        1361  i hope that once secretary clinton has testifi...
#
#             speaker                date  numOccurrences  \
# 0  dianne feinstein 2015-12-11 19:13:13             5.0
# 1  dianne feinstein 2015-03-08 08:00:00             5.0
# 2  dianne feinstein 2015-10-21 20:07:39             1.0
#
#                                           congresses unaccentedMiddleName  \
# 0  [{'position': 'Senator', 'congressNumber': 114...                  NaN
# 1  [{'position': 'Senator', 'congressNumber': 114...                  NaN
# 2  [{'position': 'Senator', 'congressNumber': 114...                  NaN
#
#   nickName position stateName   parties  \
# 0      NaN  Senator        CA  Democrat
# 1      NaN  Senator        CA  Democrat
# 2      NaN  Senator        CA  Democrat
#
#                                           NLTK score  neg    neu    pos  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.0  1.000  0.000
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.0  1.000  0.000
# 2  {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'comp...  0.0  0.745  0.255
#
#    compound
# 0     0.000
# 1     0.000
# 2     0.802

# %% [markdown]
# Subset into parties

# %%
dem = df[df["parties"] == "Democrat"]
rep = df[df["parties"] == "Republican"]

# %% [markdown]
# Let's start with democrats and subset within the subset into years

# %%
dem_2015 = dem[(dem['date']> "2015-01-01") & (dem['date']< "2015-12-31")]
dem_2016 = dem[(dem['date']> "2016-01-01") & (dem['date']< "2016-12-31")]
dem_2017 = dem[(dem['date']> "2017-01-01") & (dem['date']< "2017-12-31")]
dem_2018 = dem[(dem['date']> "2018-01-01") & (dem['date']< "2018-12-31")]
dem_2019 = dem[(dem['date']> "2019-01-01") & (dem['date']< "2019-12-31")]
dem_2020 = dem[(dem['date']> "2020-01-01") & (dem['date']< "2020-12-31")]

# %% [markdown]
# Preprocessing the raw text

# %%
STOPWORDS = spacy.lang.en.stop_words.STOP_WORDS

processed_docs = []
for doc in nlp.pipe(dem_2015['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_dem_2015 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(dem_2016['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_dem_2016 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(dem_2017['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_dem_2017 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(dem_2018['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_dem_2018 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(dem_2019['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_dem_2019 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(dem_2020['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_dem_2020 = processed_docs
del processed_docs

# %% [markdown]
# Bigrams for every subset

# %%
from gensim.models.phrases import Phrases

# %%
# Add bigrams to docs (only ones that appear 15 times or more).
bigram_15 = Phrases(docs_dem_2015, min_count=15)

for idx in range(len(docs_dem_2015)):
    for token in bigram_15[docs_dem_2015[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs_dem_2015[idx].append(token)

# %%
# Add bigrams to docs (only ones that appear 15 times or more).
bigram_16 = Phrases(docs_dem_2016, min_count=15)

for idx in range(len(docs_dem_2016)):
    for token in bigram_16[docs_dem_2016[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs_dem_2016[idx].append(token)

# %%
# Add bigrams to docs (only ones that appear 15 times or more).
bigram_17 = Phrases(docs_dem_2017, min_count=15)

for idx in range(len(docs_dem_2017)):
    for token in bigram_17[docs_dem_2017[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs_dem_2017[idx].append(token)

# %%
# Add bigrams to docs (only ones that appear 15 times or more).
bigram_18 = Phrases(docs_dem_2018, min_count=15)

for idx in range(len(docs_dem_2018)):
    for token in bigram_18[docs_dem_2018[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs_dem_2018[idx].append(token)

# %%
# Add bigrams to docs (only ones that appear 15 times or more).
bigram_19 = Phrases(docs_dem_2019, min_count=15)

for idx in range(len(docs_dem_2019)):
    for token in bigram_19[docs_dem_2019[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs_dem_2019[idx].append(token)

# %%
# Add bigrams to docs (only ones that appear 15 times or more).
bigram_20 = Phrases(docs_dem_2020, min_count=15)

for idx in range(len(docs_dem_2020)):
    for token in bigram_20[docs_dem_2020[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs_dem_2020[idx].append(token)

# %% [markdown]
# Create a dictionary representation of the documents, and filter out frequent and rare words for every subset.

# %%
from gensim.corpora import Dictionary
dictionary_dem_2015 = Dictionary(docs_dem_2015)
dictionary_dem_2016 = Dictionary(docs_dem_2016)
dictionary_dem_2017 = Dictionary(docs_dem_2017)
dictionary_dem_2018 = Dictionary(docs_dem_2018)
dictionary_dem_2019 = Dictionary(docs_dem_2019)
dictionary_dem_2020 = Dictionary(docs_dem_2020)

# Remove rare and common tokens.
# Filter out words that occur too frequently or too rarely.
max_freq = 0.5
min_wordcount = 5

dictionary_dem_2015.filter_extremes(no_below=min_wordcount, no_above=max_freq)
dictionary_dem_2016.filter_extremes(no_below=min_wordcount, no_above=max_freq)
dictionary_dem_2017.filter_extremes(no_below=min_wordcount, no_above=max_freq)
dictionary_dem_2018.filter_extremes(no_below=min_wordcount, no_above=max_freq)
dictionary_dem_2019.filter_extremes(no_below=min_wordcount, no_above=max_freq)
dictionary_dem_2020.filter_extremes(no_below=min_wordcount, no_above=max_freq)


# Bag-of-words representation of the documents.
corpus_dem_2015 = [dictionary_dem_2015.doc2bow(doc) for doc in docs_dem_2015]
corpus_dem_2016 = [dictionary_dem_2016.doc2bow(doc) for doc in docs_dem_2016]
corpus_dem_2017 = [dictionary_dem_2017.doc2bow(doc) for doc in docs_dem_2017]
corpus_dem_2018 = [dictionary_dem_2018.doc2bow(doc) for doc in docs_dem_2018]
corpus_dem_2019 = [dictionary_dem_2019.doc2bow(doc) for doc in docs_dem_2019]
corpus_dem_2020 = [dictionary_dem_2020.doc2bow(doc) for doc in docs_dem_2020]
#MmCorpus.serialize("models/corpus.mm", corpus)

print('Number of unique tokens 2015: %d' % len(dictionary_dem_2015))
print('Number of chunks 2015: %d' % len(corpus_dem_2015))

print('Number of unique tokens 2016: %d' % len(dictionary_dem_2016))
print('Number of chunks 2016: %d' % len(corpus_dem_2016))

print('Number of unique tokens 2017: %d' % len(dictionary_dem_2017))
print('Number of chunks 2017: %d' % len(corpus_dem_2017))

print('Number of unique tokens 2018: %d' % len(dictionary_dem_2018))
print('Number of chunks 2018: %d' % len(corpus_dem_2018))

print('Number of unique tokens 2019: %d' % len(dictionary_dem_2019))
print('Number of chunks 2019: %d' % len(corpus_dem_2019))

print('Number of unique tokens 2020: %d' % len(dictionary_dem_2020))
print('Number of chunks 2020: %d' % len(corpus_dem_2020))
# Out:
# Number of unique tokens 2015: 2281
# Number of chunks 2015: 5336
# Number of unique tokens 2016: 2460
# Number of chunks 2016: 6259
# Number of unique tokens 2017: 4195
# Number of chunks 2017: 11870
# Number of unique tokens 2018: 4036
# Number of chunks 2018: 11148
# Number of unique tokens 2019: 3936
# Number of chunks 2019: 11964
# Number of unique tokens 2020: 1539
# Number of chunks 2020: 3038

# %% [markdown]
# LDA Modeling: 3 topic per year

# %%
from gensim.models import LdaMulticore
params = {'passes': 20, 'random_state': 16}
base_models = dict()
num_topics = 3

# %%
# %time model_dem_2015 = gensim.models.LdaModel(corpus_dem_2015, num_topics=num_topics, \
                                  id2word=dictionary_dem_2015, \
                                  passes=10, alpha=[0.01]*num_topics, \
                                  eta=[0.01]*len(dictionary_dem_2015.keys()))
# Out:
# CPU times: user 31.4 s, sys: 292 ms, total: 31.6 s
# Wall time: 34.2 s

# %%
# %time model_dem_2016 = gensim.models.LdaModel(corpus_dem_2016, num_topics=num_topics, \
                                  id2word=dictionary_dem_2016, \
                                  passes=15, alpha=[0.01]*num_topics, \
                                  eta=[0.01]*len(dictionary_dem_2016.keys()))
# Out:
# CPU times: user 38.9 s, sys: 180 ms, total: 39.1 s
# Wall time: 39.3 s

# %%
# %time model_dem_2017 = gensim.models.LdaModel(corpus_dem_2017, num_topics=num_topics, \
                                  id2word=dictionary_dem_2017, \
                                  passes=25, alpha=[0.01]*num_topics, \
                                  eta=[0.01]*len(dictionary_dem_2017.keys()))
# Out:
# CPU times: user 2min 3s, sys: 631 ms, total: 2min 4s
# Wall time: 2min 6s

# %%
# %time model_dem_2018 = gensim.models.LdaModel(corpus_dem_2018, num_topics=num_topics, \
                                  id2word=dictionary_dem_2018, \
                                  passes=20, alpha=[0.01]*num_topics, \
                                  eta=[0.01]*len(dictionary_dem_2018.keys()))
# Out:
# CPU times: user 1min 40s, sys: 1.03 s, total: 1min 41s
# Wall time: 1min 45s

# %%
# %time model_dem_2019 = gensim.models.LdaModel(corpus_dem_2019, num_topics=num_topics, \
                                  id2word=dictionary_dem_2019, \
                                  passes=20, alpha=[0.01]*num_topics, \
                                  eta=[0.01]*len(dictionary_dem_2019.keys()))
# Out:
# CPU times: user 1min 58s, sys: 1.37 s, total: 2min
# Wall time: 2min 4s

# %%
# %time model_dem_2020 = gensim.models.LdaModel(corpus_dem_2020, num_topics=num_topics, \
                                  id2word=dictionary_dem_2020, \
                                  passes=25, alpha=[0.01]*num_topics, \
                                  eta=[0.01]*len(dictionary_dem_2020.keys()))
# Out:
# CPU times: user 42.2 s, sys: 425 ms, total: 42.6 s
# Wall time: 44.2 s

# %% [markdown]
# Let's discover what the topic are

# %%
for i,topic in model_dem_2015.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 0.042*"republicans" + 0.020*"republican" + 0.015*"woman" + 0.013*"health" + 0.012*"care" + 0.009*"committee" + 0.009*"want" + 0.008*"time" + 0.007*"think" + 0.007*"president"
#
# 1: 0.044*"republican" + 0.024*"trump" + 0.021*"party" + 0.019*"donald" + 0.018*"donald_trump" + 0.015*"donald trump" + 0.014*"republican_party" + 0.012*"candidate" + 0.011*"people" + 0.011*"republicans"
#
# 2: 0.043*"republicans" + 0.029*"republican" + 0.015*"democrats" + 0.014*"work" + 0.013*"house" + 0.012*"bill" + 0.010*"vote" + 0.009*"congress" + 0.008*"need" + 0.007*"security"

# %%
for i,topic in model_dem_2016.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 0.080*"donald" + 0.079*"donald_trump" + 0.066*"donald trump" + 0.018*"republican" + 0.015*"party" + 0.011*"clinton" + 0.010*"republican_party" + 0.009*"people" + 0.008*"hillary" + 0.008*"think"
#
# 1: 0.030*"republicans" + 0.020*"know" + 0.019*"donald" + 0.019*"donald_trump" + 0.017*"republican" + 0.016*"think" + 0.014*"donald trump" + 0.013*"president" + 0.011*"people" + 0.010*"want"
#
# 2: 0.032*"republicans" + 0.028*"republican" + 0.011*"democrats" + 0.011*"mccain" + 0.010*"house" + 0.010*"people" + 0.010*"john" + 0.009*"congress" + 0.009*"work" + 0.009*"john_mccain"

# %%
for i,topic in model_dem_2017.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 0.056*"president" + 0.048*"trump" + 0.043*"president_trump" + 0.007*"administration" + 0.007*"american" + 0.006*"country" + 0.006*"congress" + 0.005*"action" + 0.005*"people" + 0.005*"republicans"
#
# 1: 0.065*"trump" + 0.045*"donald" + 0.044*"donald_trump" + 0.034*"donald trump" + 0.021*"president" + 0.011*"president_trump" + 0.010*"think" + 0.010*"house" + 0.009*"white" + 0.009*"investigation"
#
# 2: 0.038*"republicans" + 0.029*"republican" + 0.018*"care" + 0.018*"health" + 0.017*"bill" + 0.012*"tax" + 0.012*"work" + 0.012*"people" + 0.012*"democrats" + 0.010*"health_care"

# %%
for i,topic in model_dem_2018.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 0.027*"republicans" + 0.011*"work" + 0.011*"people" + 0.010*"republican" + 0.009*"care" + 0.009*"family" + 0.009*"health" + 0.008*"bill" + 0.008*"democrats" + 0.007*"tax"
#
# 1: 0.053*"republican" + 0.033*"republicans" + 0.018*"house" + 0.016*"think" + 0.015*"party" + 0.014*"democrats" + 0.010*"senate" + 0.010*"vote" + 0.009*"democratic" + 0.008*"people"
#
# 2: 0.078*"trump" + 0.054*"president" + 0.040*"president_trump" + 0.028*"donald" + 0.028*"donald_trump" + 0.022*"donald trump" + 0.006*"investigation" + 0.005*"people" + 0.005*"country" + 0.005*"policy"

# %%
for i,topic in model_dem_2019.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 0.030*"republicans" + 0.027*"republican" + 0.024*"president" + 0.015*"democrats" + 0.012*"people" + 0.011*"work" + 0.011*"senate" + 0.009*"bill" + 0.008*"care" + 0.008*"want"
#
# 1: 0.059*"donald" + 0.051*"donald_trump" + 0.046*"donald trump" + 0.017*"think" + 0.016*"president" + 0.012*"people" + 0.012*"republican" + 0.011*"country" + 0.011*"party" + 0.010*"want"
#
# 2: 0.062*"president" + 0.011*"congress" + 0.010*"impeachment" + 0.009*"house" + 0.008*"national" + 0.007*"election" + 0.007*"power" + 0.007*"investigation" + 0.007*"committee" + 0.006*"office"

# %%
for i,topic in model_dem_2020.show_topics(formatted=True, num_topics=num_topics, num_words=10):
    print(str(i)+": "+ topic)
    print()
# Out:
# 0: 0.055*"donald" + 0.048*"donald trump" + 0.036*"donald_trump" + 0.024*"president" + 0.019*"beat" + 0.013*"beat_donald" + 0.012*"election" + 0.012*"woman" + 0.009*"biden" + 0.008*"people"
#
# 1: 0.052*"president" + 0.017*"republicans" + 0.015*"senate" + 0.015*"house" + 0.013*"republican" + 0.010*"congress" + 0.010*"american" + 0.009*"vote" + 0.008*"war" + 0.008*"people"
#
# 2: 0.025*"president" + 0.022*"republican" + 0.021*"donald" + 0.019*"donald_trump" + 0.014*"republicans" + 0.013*"donald trump" + 0.013*"people" + 0.011*"think" + 0.009*"need" + 0.009*"democrats"

# %% [markdown]
# Visualization per year of the topics

# %%
# %matplotlib inline
vis_dem_2015 = pyLDAvis.gensim_models.prepare(topic_model=model_dem_2015, corpus=corpus_dem_2015, dictionary=dictionary_dem_2015)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis_dem_2015)
# Topic 1: Health care and planned parenthood (women)
# Topic 2: Security, vote on a bill, congress and senate 
# Topic 3: Presidential elections: candidates from the republican party
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1670765077932007758212130"></div>
# <script type="text/javascript">
#
# var ldavis_el1670765077932007758212130_data = {"mdsDat": {"x": [-0.11759483346667554, -0.1531375487718339, 0.27073238223850943], "y": [0.1441968735774822, -0.1321055501537094, -0.012091323423772848], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [43.16397689219639, 35.39294672213805, 21.44307638566556]}, "tinfo": {"Term": ["trump", "donald", "donald_trump", "donald trump", "party", "democrats", "bill", "united", "republicans", "paul", "states", "candidate", "vote", "house", "the united states", "security", "health", "care", "presidential", "republican_party", "united_states", "woman", "rubio", "pass", "colleague", "change", "marco", "ryan", "marco_rubio", "boehner", "care", "parenthood", "planned", "health_care", "affordable", "woman_health", "dollar", "planned_parenthood", "bank", "republican_colleague", "decision", "attempt", "tax", "governor", "defund", "aisle", "corporation", "shut_government", "affordable_care", "invest", "special_interest", "government_shutdown", "education", "mccarthy", "billion", "single", "wealthy", "street", "exactly", "level", "hillary_clinton", "colleague", "health", "class", "middle_class", "million", "past", "hillary clinton", "big", "action", "woman", "government", "clinton", "pay", "middle", "effort", "republican", "party", "right", "republic

pyLDAvis.enable_notebook()
pyLDAvis.display(vis_dem_2017)

# Topic 1: Trump and Elections
# Topic 2: Healthcare
# Topic 3: Tax Cut
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1670765088816168706111569"></div>
# <script type="text/javascript">
#
# var ldavis_el1670765088816168706111569_data = {"mdsDat": {"x": [0.2473394739650925, -0.02127455141419592, -0.22606492255089655], "y": [0.08932402925377282, -0.20648621284558402, 0.11716218359181119], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [44.881286400583, 34.57826255194858, 20.54045104746842]}, "tinfo": {"Term": ["trump", "president", "president_trump", "republicans", "tax", "republican", "care", "donald", "donald_trump", "health", "donald trump", "family", "health_care", "bill", "cut", "democrats", "middle", "work", "class", "plan", "budget", "affordable", "middle_class", "wealthy", "vote", "million", "coverage", "insurance", "job", "americans", "trump", "donald", "donald_trump", "donald trump", "russia", "united", "states", "united_states", "the united states", "russian", "court", "director", "donald trump's", "justice", "general", "fbi", "nominee", "border", "attorney", "secretary", "fire", "national_security", "daca", "clinton", "judge", "official", "immigrant", "tie", "russians", "tweet", "president_trump", "president", "campaign", "investigation", "world", "action", "administration", "comey", "election", "decision", "military", "white", "national", "security", "government", "country", "clear", "policy", "american", "people", "know", "think", "right", "congress", "need", "house", "want", "come", "care", "health_care", "affordable", "coverage", "insurance", "repeal", "republican_colleague", "affordable_care", "trumpcare", "health_insurance", "republican_leadership", "aca", "fix", "care_act", "gun", "market", "democrat_republican", "existing", "mccain", "quality", "caucus", "member_congress", "paul ryan", "health_coverage", "cbo", "repeal_affordable", "strip", "patient", "john_mccain", "paul_ryan", "health", "democrat", "healthcare", "democratic", "democrats", "colleague", "improve", "republican", "republicans", "lose", "vote", "senate", "senator", "bill", "cost", "bipartisan", "act", "pass", "house", "million", "legislation", "work", "people", "americans", "think", "congress", "know", "need", "time", "want", "come", "american", "tax", "middle", "class", "middle_class", "wealthy", "corporation", "republican_party", "tax_cut", "billion", "rich", "the republican party", "taxis", "dollar", "infrastructure", "tax_reform", "tax_plan", "street", "local", "tax_break", "massive", "deficit", "paris", "billionaire", "wall_street", "industry", "trillion", "investment", "education", "scalise", "debt", "cut", "budget", "family", "program", "work_family", "break", "job", "economy", "pay", "benefit", "reform", "plan", "wall", "new", "climate", "republicans", "work", "republican", "big", "promise", "americans", "bill", "state", "party", "people", "help", "american", "america", "million"], "Freq": [6991.0, 5477.0, 3914.0, 3972.0, 1232.0, 3192.0, 1703.0, 2167.0, 2137.0, 1647.0, 1670.0, 1047.0, 944.0, 1614.0, 645.0, 1211.0, 397.0, 1620.0, 376.0, 839.0, 400.0, 521.0, 336.0, 312.0, 981.0, 802.0, 415.0, 411.0, 452.0, 1078.0, 6991.147268910946, 2167.1430658161157, 2137.851630945326, 1670.969846084407, 372.5030693484082, 361.2877420896186, 316.1864201225341, 315.58550436658453, 272.65606230325744, 270.4403598136147, 235.33472558239245, 231.2293280948154, 224.89014112989332, 216.6252246799694, 198.20597575886134, 192.1150082896942, 187.17465686467793, 165.6495838791903, 165.40538629715323, 159.25211403744348, 157.09038191020542, 154.4751615752364, 153.31117789878624, 148.34920578152946, 145.4402578808476, 141.7797235721615, 137.04992979190055, 134.82976367547263, 131.34540313646258, 127.271588133196, 3911.790465538303, 5399.153115473831, 479.9479363677222, 410.6406453214934, 243.7659586261752, 394.2476039841652, 579.028315512525, 180.2797599890339, 332.9033998745714, 351.6448668542318, 178.65941696991544, 421.4899551839015, 279.42231606007033, 295.74024292790483, 304.55516189076036, 473.3784076622419, 341.72866422242373, 292.22953071722316, 536.8851227089556, 674.8967897126327, 460.15054267670195, 484.5118552671916, 395.1204290051096,  ...

# %%
# %matplotlib inline
vis_dem_2018 = pyLDAvis.gensim_models.prepare(topic_model=model_dem_2018, corpus=corpus_dem_2018, dictionary=dictionary_dem_2018)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis_dem_2018)

# Topic 1: Trump and investigation, intelligence
# Topic 2: Health Care
# Topic 3: Mccain
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el167076508882624205480030"></div>
# <script type="text/javascript">
#
# var ldavis_el167076508882624205480030_data = {"mdsDat": {"x": [-0.23850801804536123, 0.10149534232107316, 0.1370126757242882], "y": [0.018634741334560598, -0.19702298353115485, 0.1783882421965943], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [40.37110928209327, 34.10916558076478, 25.519725137141958]}, "tinfo": {"Term": ["trump", "republican", "president_trump", "president", "donald", "donald_trump", "donald trump", "republicans", "party", "house", "democrats", "think", "health", "care", "democratic", "democrat", "senate", "tax", "republican_party", "vote", "bill", "family", "john", "majority", "win", "health_care", "ryan", "cut", "the republican party", "leadership", "president_trump", "donald", "donald_trump", "donald trump", "united", "russia", "states", "united_states", "donald trump's", "putin", "the united states", "intelligence", "department", "russian", "nuclear", "meeting", "clinton", "agency", "national_security", "racist", "obama", "climate", "iran", "russians", "hillary", "enforcement", "farm", "director", "interference", "behavior", "trump", "counsel", "special_counsel", "president", "ally", "investigation", "foreign", "official", "secretary", "justice", "world", "mueller", "policy", "campaign", "action", "national", "administration", "law", "country", "attack", "election", "american", "people", "think", "america", "need", "congress", "come", "time", "want", "know", "health", "tax", "health_care", "cut", "pay", "million", "kavanaugh", "gun", "percent", "protection", "supreme", "supreme_court", "dreamer", "cost", "condition", "corporation", "dollar", "billion", "medicare", "pre", "affordable", "social", "infrastructure", "existing", "trillion", "tax_cut", "floor", "insurance", "wealthy", "healthcare", "budget", "care", "court", "program", "bill", "family", "funding", "americans", "republicans", "year", "work", "bipartisan", "pass", "child", "people", "democrats", "fight", "plan", "vote", "right", "act", "republican", "woman", "american", "congress", "want", "need", "support", "time", "party", "republican_party", "ryan", "the republican party", "mccain", "paul", "republican_colleague", "john mccain", "speaker", "republican_leadership", "john_mccain", "paul ryan", "paul_ryan", "mcconnell", "democrat", "pelosi", "aisle", "primary", "mitch", "house_senate", "moderate", "anybody", "mitch_mcconnell", "nancy", "democratic_party", "control_house", "mitch mcconnell", "federal_government", "nancy_pelosi", "wing", "win", "democratic", "republican", "majority", "john", "house", "colleague", "control", "candidate", "leadership", "senate", "think", "the white house", "district", "thing", "republicans", "democrats", "white_house", "vote", "white", "run", "know", "like", "congress", "want", "need", "people", "work", "come", "time", "right", "country"], "Freq": [6063.0, 3193.0, 3053.0, 4536.0, 2162.0, 2119.0, 1665.0, 3573.0, 745.0, 1103.0, 1215.0, 1177.0, 589.0, 613.0, 502.0, 398.0, 678.0, 485.0, 305.0, 945.0, 642.0, 717.0, 339.0, 332.0, 295.0, 330.0, 259.0, 317.0, 240.0, 399.0, 3053.305290934031, 2162.5230950726336, 2119.786142723681, 1665.5886203231416, 298.9881908299211, 279.2764371095289, 268.81393565489924, 266.59764511097296, 249.57814382091647, 232.85776376008354, 211.832820688282, 195.8526684011405, 191.87978695939844, 147.71050238496173, 138.37596748856907, 127.77075456573797, 117.81924963648572, 114.32401547320171, 110.00214133432955, 101.38071553637803, 100.27575278663434, 99.25210123838491, 97.92222829866458, 92.63965379752896, 89.07449379393015, 84.49243277512767, 78.38571949192286, 78.19761001662472, 77.77141201990601, 75.85626876160212, 5988.325608205377, 155.4012152483232, 136.4355074901307, 4180.995803469112, 163.21901384403122, 451.1962336154176, 134.5015290791984, 145.39261318099855, 145.2126975798091, 252.08003659827213, 187.23850413276014, 194.2383855532167, 407.31360912686625, 341.92086381294456, 247.46833778099776, 217.29393916835477, 334.9979904653475, 259.3935981664998, 416.27028450487063, 253.7952636 ...

# %%
# %matplotlib inline
vis_dem_2019 = pyLDAvis.gensim_models.prepare(topic_model=model_dem_2019, corpus=corpus_dem_2019, dictionary=dictionary_dem_2019)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis_dem_2019)

# Topic 1: Healthcare
# Topic 2: National security , investigation
# Topic 3: TRUMP and elections
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1670765088837444575583858"></div>
# <script type="text/javascript">
#
# var ldavis_el1670765088837444575583858_data = {"mdsDat": {"x": [0.05969805890481574, -0.24800017677870037, 0.18830211787388454], "y": [-0.19939436785508388, 0.05877329859599784, 0.14062106925908607], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [35.492619405883254, 32.88690179847782, 31.620478795638927]}, "tinfo": {"Term": ["donald", "donald_trump", "donald trump", "president", "republican", "party", "impeachment", "think", "democrats", "republicans", "bill", "care", "investigation", "national", "border", "senate", "congress", "beat", "report", "win", "health", "colleague", "foreign", "work", "pass", "democrats_republicans", "wall", "committee", "abuse", "republican_party", "bill", "care", "border", "health", "pass", "democrats_republicans", "wall", "tax", "republican_colleague", "health_care", "legislation", "shutdown", "majority", "mcconnell", "worker", "address", "mitch", "child", "mitch mcconnell", "democrat_republican", "solution", "mitch_mcconnell", "funding", "agenda", "protection", "border_security", "percent", "proposal", "billion", "border_wall", "colleague", "bipartisan", "senate", "democrats", "pay", "republicans", "work", "family", "republican", "democrat", "stop", "government", "support", "people", "vote", "president", "need", "want", "american", "americans", "house", "congress", "come", "year", "country", "think", "investigation", "report", "foreign", "abuse", "john", "national_security", "mueller", "ukraine", "witness", "attorney", "abuse_power", "inquiry", "counsel", "conduct", "attorney_general", "obstruct", "ally", "king", "information", "impeachment_inquiry", "special_counsel", "investigate", "barr", "steve", "
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics_dem_2015]) \
  .reset_index(drop=True).fillna(0)

document_topic_dem_2015['max_topic'] = document_topic_dem_2015.apply(lambda x: x.argmax(), axis=1)

dem_2015 = pd.concat([dem_2015, document_topic_dem_2015[['max_topic']]], axis=1,)

# %%
topics_dem_2016 = [model_dem_2016[corpus_dem_2016[i]] for i in range(len(docs_dem_2016))]

document_topic_dem_2016 = \
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics_dem_2016]) \
  .reset_index(drop=True).fillna(0)

document_topic_dem_2016['max_topic'] = document_topic_dem_2016.apply(lambda x: x.argmax(), axis=1)

dem_2016 = pd.concat([dem_2016, document_topic_dem_2016[['max_topic']]], axis=1,)

# %%
topics_dem_2017 = [model_dem_2017[corpus_dem_2017[i]] for i in range(len(docs_dem_2017))]

document_topic_dem_2017 = \
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics_dem_2017]) \
  .reset_index(drop=True).fillna(0)

document_topic_dem_2017['max_topic'] = document_topic_dem_2017.apply(lambda x: x.argmax(), axis=1)

dem_2017 = pd.concat([dem_2017, document_topic_dem_2017[['max_topic']]], axis=1,)

# %%
topics_dem_2018 = [model_dem_2018[corpus_dem_2018[i]] for i in range(len(docs_dem_2018))]

document_topic_dem_2018 = \
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics_dem_2018]) \
  .reset_index(drop=True).fillna(0)

document_topic_dem_2018['max_topic'] = document_topic_dem_2018.apply(lambda x: x.argmax(), axis=1)

dem_2018 = pd.concat([dem_2018, document_topic_dem_2018[['max_topic']]], axis=1,)

# %%
topics_dem_2019 = [model_dem_2019[corpus_dem_2019[i]] for i in range(len(docs_dem_2019))]

document_topic_dem_2019 = \
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics_dem_2019]) \
  .reset_index(drop=True).fillna(0)

document_topic_dem_2019['max_topic'] = document_topic_dem_2019.apply(lambda x: x.argmax(), axis=1)

dem_2019 = pd.concat([dem_2019, document_topic_dem_2019[['max_topic']]], axis=1,)

# %%
topics_dem_2020 = [model_dem_2020[corpus_dem_2020[i]] for i in range(len(docs_dem_2020))]

document_topic_dem_2020 = \
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics_dem_2020]) \
  .reset_index(drop=True).fillna(0)

document_topic_dem_2020['max_topic'] = document_topic_dem_2020.apply(lambda x: x.argmax(), axis=1)

dem_2020 = pd.concat([dem_2020, document_topic_dem_2020[['max_topic']]], axis=1,)

# %%
# %matplotlib inline
import seaborn as sns; sns.set(rc={'figure.figsize':(10,20)})
sns.heatmap(document_topic_dem_2015.drop(['max_topic'], axis = 1).loc[document_topic_dem_2015.drop(['max_topic'], axis = 1).idxmax(axis=1).sort_values().index])
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(10,5)})
document_topic_dem_2015.drop(['max_topic'], axis = 1).idxmax(axis=1).value_counts().plot.bar(color='lightblue')
# Out:
# <AxesSubplot:>

# %%
dem_2015["date"] = pd.to_datetime(dem_2015["date"])

# Global average per month
# g_all = dem_2015.set_index("date").groupby(pd.Grouper(freq="M"))["compound"].mean()
# g_ma = g_all.rolling(5, center=True, closed="both").mean()
# Average per party per month
g = pd.DataFrame(dem_2015.set_index("date").groupby([pd.Grouper(freq="M"), "max_topic"])["compound"].mean()).reset_index("max_topic")
g_0 = g[g["max_topic"] == 0]
g_1 = g[g["max_topic"] == 1]
g_2 = g[g["max_topic"] == 2]

# %%
# ci95_hi.append(m + 1.95*s/math.sqrt(c))
# ci95_lo.append(m - 1.95*s/math.sqrt(c))
g = pd.DataFrame(dem_2015.set_index("date").groupby([pd.Grouper(freq="M"), "max_topic"])["compound"].agg(['mean', 'count', 'std'])).reset_index("max_topic")
g['ci95_hi'] = (g['mean'] + 1.95*g['std']/g['count']**0.5)
g['ci95_lo'] = (g['mean'] - 1.95*g['std']/g['count']**0.5)
g_0 = g[g["max_topic"] == 0]
g_1 = g[g["max_topic"] == 1]
g_2 = g[g["max_topic"] == 2]

# %%
g_0
# Out:
#             max_topic      mean  count       std   ci95_hi   ci95_lo
# date
# 2015-01-31        0.0  0.232620     54  0.467685  0.356726  0.108515
# 2015-02-28        0.0  0.093518     39  0.543520  0.263232 -0.076196
# 2015-03-31        0.0  0.126163     57  0.514494  0.259049 -0.006722
# 2015-04-30        0.0  0.133977     44  0.476317  0.274002 -0.006047
# 2015-05-31        0.0  0.117297     37  0.414697  0.250240 -0.015646
# 2015-06-30        0.0  0.049939     44  0.427923  0.175737 -0.075859
# 2015-07-31        0.0 -0.068903     94  0.576045  0.046955 -0.184761
# 2015-08-31        0.0 -0.017836    116  0.590211  0.089023 -0.124696
# 2015-09-30        0.0 -0.008695    130  0.545462  0.084594 -0.101983
# 2015-10-31        0.0  0.098543    190  0.493073  0.168297  0.028789
# 2015-11-30        0.0  0.096944     55  0.456122  0.216875 -0.022988
# 2015-12-31        0.0  0.002676    189  0.535780  0.078672 -0.073320

# %%
# Plot average score per month and party
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(g_0.index, g_0["mean"], label="Topic 0", alpha=0.6)
ax.fill_between(g_0.index, (g_0['ci95_lo']), (g_0['ci95_hi']), alpha=.1)

ax.plot(g_1.index, g_1["mean"], label="Topic 1", alpha=0.6)
ax.fill_between(g_1.index, (g_1['ci95_lo']), (g_1['ci95_hi']), alpha=.1)

ax.plot(g_2.index, g_2["mean"], label="Topic 2", alpha=0.6)
ax.fill_between(g_2.index, (g_2['ci95_lo']), (g_2['ci95_hi']),  alpha=.1)

plt.title("Average sentiment per topic in 2015 by democrats ")
plt.xlabel("Date")
plt.ylabel("Sentiment")

plt.legend()

plt.show()

# %%
# Republicans

# %%
rep_2015 = rep[(rep['date']> "2015-01-01") & (rep['date']< "2015-12-31")]
rep_2016 = rep[(rep['date']> "2016-01-01") & (rep['date']< "2016-12-31")]
rep_2017 = rep[(rep['date']> "2017-01-01") & (rep['date']< "2017-12-31")]
rep_2018 = rep[(rep['date']> "2018-01-01") & (rep['date']< "2018-12-31")]
rep_2019 = rep[(rep['date']> "2019-01-01") & (rep['date']< "2019-12-31")]
rep_2020 = rep[(rep['date']> "2020-01-01") & (rep['date']< "2020-12-31")]

# %%
processed_docs = []
for doc in nlp.pipe(rep_2015['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_rep_2015 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(rep_2016['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_rep_2016 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(rep_2017['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_rep_2017 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(rep_2018['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_rep_2018 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(rep_2019['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_rep_2019 = processed_docs
del processed_docs

# %%
processed_docs = []
for doc in nlp.pipe(rep_2020['quotation'], n_process=5, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
    
docs_rep_2020 = processed_docs
del processed_docs
