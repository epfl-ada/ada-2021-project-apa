# %%
# Built-in
import json
import bz2
import os
import time
import csv
import requests

# Third parties
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from bs4 import BeautifulSoup
# from tqdm.contrib.concurrent import process_map
# from pandarallel import pandarallel
# pandarallel.initialize(progress_bar=True)
# tqdm for pandas
tqdm.pandas()

# Config part
DATA_PATH = "data"
PKL_PATH = os.path.join(DATA_PATH, "pkl")
RESOURCES_PATH = os.path.join(DATA_PATH, "resources")

# for windows pickle
#!pip3 install pickle5
import pickle5 as pickle

def load_df(
    file_name: str, mode: str = "pandas", save: bool = True, chunksize: int = 1_000_000
) -> pd.DataFrame:
    """
    Load a dataset in DataFrame from a .json.bz2 archive.

    file_name: str
        Name of .json.bz2 archive to load from `DATA_PATH`.

    mode: str = "pandas" | "bz2"
        Either use pandas read_json function or homemade bz2 function. This is usually faster (but makes my computer crash for some reason).

    save: bool
        Save the dataframe as a pickle file in `PKL_PATH`.
    """

    file_path = os.path.join(DATA_PATH, file_name)

    if mode == "bz2":
        keys = ["quoteID", "quotation", "speaker", "date", "numOccurrences", "phase"]

        with bz2.open(file_path, "rb") as quote_file:
            df = pd.DataFrame(
                [
                    dict(zip(keys, map(json.loads(instance).get, keys)))
                    for instance in tqdm(quote_file)
                ]
            )
    else:
        if not save:
            print("Please enable save option.")
            return

        with pd.read_json(file_path, lines=True, chunksize=chunksize) as df_reader:
            for i, chunk in enumerate(df_reader):
                file_name = file_name.strip(".json.bz2")
                pkl_path = os.path.join(PKL_PATH, f"{file_name}-{i:03d}.pkl")
                chunk.to_pickle(pkl_path)

                if i == 1:
                    break
        return

    file_name = file_name.strip(".json.bz2")
    pkl_path = os.path.join(PKL_PATH, f"{file_name}.pkl")

    if save and not os.path.exists(pkl_path):
        df.to_pickle(os.path.join(PKL_PATH, pkl_path))

    return df

def to_csv(file_name: str, pol_lst: list) -> None:
    """
    Write list to csv
    """

    csv_path = os.path.join("data", "resources", file_name)

    with open(csv_path, "w", encoding='utf-8') as f:
        writer = csv.writer(f, delimiter=" ")
        writer.writerow(["Name", "Party"])

        for member in pol_lst:
            writer.writerow([el for el in member])

def get_pkl_year(year: int) -> list:
    """
    Returns a list of the pkl files present in `data/pkl/{year}`.
    """

    dirs = os.listdir(os.path.join(PKL_PATH, str(year)))

    return [os.path.join(str(year), dir) for dir in dirs]

# %% [markdown]
# # Loading data
# At first we will simply load the data from the quote bank, display examples, and then we start extracting relevant subsets.

# %%
quote_filepath = os.path.join('data/quotes-2019-nytimes.json.bz2')
politicians_filepath = os.path.join('data','resources','politicians_congress.csv')
speaker_attributes_filepath = os.path.join('data/speaker_attributes.parquet')
keys = ['quoteID', 'quotation', 'speaker', 'date', 'numOccurrences', 'phase']

# %%
# Load dataframe. It is faster this way than using pd.read_json
with bz2.open(quote_filepath, 'rb') as quote_file:
    df = pd.DataFrame([dict(zip(keys,map(json.loads(instance).get, keys))) for instance in quote_file])

# Load speakers data
df_speaker_attributes = pd.read_parquet(speaker_attributes_filepath)

# %%
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2019-04-17-024782                It is not a low-income immigration,
# 1  2019-04-02-001128  a champion figure skater switching to roller s...
# 2  2019-05-09-055187  It makes it much more difficult for him to mak...
# 3  2019-10-31-056366                       It puts me in a predicament,
# 4  2019-01-04-001792                                  A Pile of Leaves.
#
#           speaker                 date  numOccurrences phase
# 0    James Fisher  2019-04-17 13:31:18               1     E
# 1     John Updike  2019-04-02 14:58:33               2     E
# 2            None  2019-05-09 18:11:29               1     E
# 3  Xavier Becerra  2019-10-31 16:45:15               3     E
# 4            None  2019-01-04 10:00:07               1     E

# %%
len(df_speaker_attributes) # 9 055 981 speakers
df_speaker_attributes.head()
# Out:
#                                              aliases            date_of_birth  \
# 0  [Washington, President Washington, G. Washingt...  [+1732-02-22T00:00:00Z]
# 1  [Douglas Noel Adams, Douglas Noël Adams, Dougl...  [+1952-03-11T00:00:00Z]
# 2      [Paul Marie Ghislain Otlet, Paul Marie Otlet]  [+1868-08-23T00:00:00Z]
# 3  [George Walker Bush, Bush Jr., Dubya, GWB, Bus...  [+1946-07-06T00:00:00Z]
# 4  [Velázquez, Diego Rodríguez de Silva y Velázqu...  [+1599-06-06T00:00:00Z]
#
#       nationality      gender   lastrevid ethnic_group US_congress_bio_ID  \
# 0  [Q161885, Q30]  [Q6581097]  1395141751         None            W000178
# 1          [Q145]  [Q6581097]  1395737157   [Q7994501]               None
# 2           [Q31]  [Q6581097]  1380367296         None               None
# 3           [Q30]  [Q6581097]  1395142029         None               None
# 4           [Q29]  [Q6581097]  1391704596         None               None
#
#                                           occupation      party  \
# 0  [Q82955, Q189290, Q131512, Q1734662, Q294126, ...  [Q327591]
# 1  [Q214917, Q28389, Q6625963, Q4853732, Q1884422...       None
# 2  [Q36180, Q40348, Q182436, Q1265807, Q205375, Q...       None
# 3  [Q82955, Q15982858, Q18814623, Q1028181, Q1408...   [Q29468]
# 4                                         [Q1028181]       None
#
#   academic_degree     id              label  \
# 0            None    Q23  George Washington
# 1            None    Q42      Douglas Adams
# 2            None  Q1868         Paul Otlet
# 3            None   Q207     George W. Bush
# 4            None   Q297    Diego Velázquez
#
#                                 candidacy  type                    religion
# 0                      [Q698073, Q697949]  item                   [Q682443]
# 1                                    None  item                        None
# 2                                    None  item                        None
# 3  [Q327959, Q464075, Q3586276, Q4450587]  item  [Q329646, Q682443, Q33203]
# 4                                    None  item                        None

# %% [markdown]
# ## Task 2
#
#
# ### Task 2.1
# Get list of US politicians with political affiliation.
#
# 2 sources:
# - https://github.com/casmlab/politicians-tweets
# - https://www.congress.gov/members?q={%22congress%22:[%22110%22,%22111%22,%22112%22,%22113%22,%22114%22,%22115%22,%22116%22,117]}
#
# Take 1st list, keep politicians whose affiliation is known. Then merge with congress list to be sure we have a good dataset.
# List of politicians is in `data/ressources/politicians.json`.

# %%
file_name = "politicians_github.json"
file_path = os.path.join("data", "resources", file_name)

with open(file_path, "r") as f:
    json = json.load(f)

# %%
json.keys()
# Out:
# dict_keys(['id', 'id_str', 'screen_name', 'confirmed_account_type', 'state', 'twitter_name', 'real_name', 'bioguide', 'office_holder', 'party', 'district', 'level', 'woman', 'birthday', 'last_updated'])

# %%
# Only keep politicians with political affiliation
politicians = []

for i in tqdm(range(1, len(json["id"]))):
    i = str(i)
    affiliation = json["party"][i]
    screen_name = json["screen_name"][i]
    elected = json["office_holder"][i] is not None

    if affiliation is not None and affiliation in ("Republican", "Democratic"):
        politicians.append((json["real_name"][i], affiliation, elected))
    elif screen_name == "realdonaldtrump":
        politicians.append(("Donald Trump", "Republican", True))
    elif screen_name == "barackobama":
        politicians.append(("Barack Obama", "Democratic", True))
# Out:
# 100%|██████████| 9979/9979 [00:00<00:00, 667064.46it/s]

# %%
# Count how many politicians are "elected" (-> congress members)
sum(pol[-1] for pol in politicians)
# Out:
# 1107

# %% [markdown]
# All politicians are in Congress!

# %%
# Sanity check
print(f"{len(politicians)}") 
politicians[:10]
# Out:
# 1107
# [('Mark Green', 'Republican', True),
#  ('Pete Stauber', 'Republican', True),
#  ('Derek Kilmer', 'Democratic', True),
#  ('Andy Harris', 'Republican', True),
#  ('Donald Payne', 'Democratic', True),
#  ('A. Ferguson', 'Republican', True),
#  ('Richard Hudson', 'Republican', True),
#  ('Edward Markey', 'Democratic', True),
#  ('Bobby Rush', 'Democratic', True),
#  ('Gregory Meeks', 'Democratic', True)]

# %%
# Write to file
to_csv("politicians_github.csv", politicians)

# %% [markdown]
# #### US Congress dataset

# %%
URL = 'https://www.congress.gov/members?q={"congress":["110","111","112","113","114","115","116",117]}&pageSize=250'

def sanitize_name(name: str) -> str:
    """
    Strip and clean name.
    "Senator Cruz, Ted" -> "Ted Cruz"
    """

    for element in ("Representative", "Senator"):
        name = name.strip(element)

    name = " ".join(name.split(",")[::-1])
    name = name.strip()
    
    return name

congress_members = []

# Download each congress page
with requests.Session() as s:
    for page_number in tqdm(range(1, 6)):
        r  = s.get(URL, params={"page": page_number})
        soup = BeautifulSoup(r.text, "html.parser")

        members = soup.find_all("li", class_="compact")

        for member in members:
            # Scrape the information
            items = member.find_all("span", class_="result-item")
            name = sanitize_name(member.span.a.text)
            
            for item in items:
                if item.strong.text == "Party:":
                    affiliation = item.span.text

            congress_members.append((name, affiliation))
# Out:
# 100%|██████████| 5/5 [00:18<00:00,  3.62s/it]

# %%
# Sanity check
len(congress_members) == 1158
# Out:
# False

# %%
# Write to file
to_csv("politicians_congress.csv", politicians)

# %% [markdown]
# #### Compare lists

# %% [markdown]
# Actually might not be useful (and less of a headache) to just take the congress list, since all politicians from the github list are elected (meaning they are or were congress members).

# %% [markdown]
# ### Task 2.2 - Extract quotes from politicians

# %% [markdown]
# I downloaded another list, from the congress [website](https://bioguide.congress.gov/search?index=%22bioguideprofiles%22&size=12&matches=[]&filters={%22jobPositions.congressAffiliation.partyAffiliation.party.name%22:[%22Democrat%22,%22Republican%22],%22jobPositions.congressAffiliation.congress.name%22:[%22The%20110th%20United%20States%20Congress%22,%22The%20111th%20United%20States%20Congress%22,%22The%20112th%20United%20States%20Congress%22,%22The%20113th%20United%20States%20Congress%22,%22The%20114th%20United%20States%20Congress%22,%22The%20115th%20United%20States%20Congress%22,%22The%20116th%20United%20States%20Congress%22,%22The%20117th%20United%20States%20Congress%22]}&sort=[{%22_score%22:true},{%22field%22:%22familyName%22,%22order%22:%22asc%22},{%22field%22:%22middleName%22,%22order%22:%22asc%22},{%22field%22:%22givenName%22,%22order%22:%22asc%22}])
#
#
# Those are the politicians from 2007 to 2009. The json is called `data/resources/congress_biolist.json`. What is nice is that we have the "congress bio ID" of each congress member, which is also present in the `speaker_attributes.parquet` file (field `US_congress_bio_ID`). We will use that to extract the tweets from the politicians.
#
# Testing with quotes from 2008.

# %%
politicians_filepath = os.path.join(RESOURCES_PATH, "new_congress_biolist.json")
# quotes_filepath = os.path.join(DATA_PATH, "quotes-2008.json.bz2")
# keys = ['quoteID', 'quotation', 'speaker', 'date', 'numOccurrences', 'phase']

politicians_df = pd.read_json(politicians_filepath)
# politicians_df = politicians_df.drop("congresses", axis=1)
# quotes_df = pd.read_pickle(os.path.join(PKL_PATH, "quotes-2008.pkl"))

# %% [markdown]
# Problem: Donald Trump is not in the dataset (because he was only President, not senator or representative and thus, not a congress member). I will manually add him now.

# %%
quotes_2020_00 = pd.read_pickle(os.path.join(PKL_PATH, "2020", "quotes-2020-000.pkl"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-21533c7bc291> in <module>
# ----> 1 quotes_2020_00 = pd.read_pickle(os.path.join(PKL_PATH, "2020", "quotes-2020-000.pkl"))
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     199         compression=compression,
#     200         is_text=False,
# --> 201         storage_options=storage_options,
#     202     ) as handles:
#     203
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\pkl\\2020\\quotes-2020-000.pkl'

# %%
quotes_2020_00[quotes_2020_00["speaker"].str.contains("Trump")]["speaker"].unique()

# %%
# Manually add Donald Trump
# Not so elegant trick to capture variations of the name
# Should refactore to another solution (alias field?) when we have time

donald_json1 = {
    "id": np.nan,
    "givenName": "Donald",
    "familyName": "Trump",
    "unaccentedGivenName": "Donald",
    "unaccentedFamilyName": "Trump",
    "birthYear": 1946,
    "deathYear": np.nan,
    "congresses": [
        {
            "position": "President",
            "congressNumber": np.nan,
            "stateName": np.nan,
            "parties": ["Republican"],
        }
    ],
    "middleName": "John",
    "unaccentedMiddleName": "John",
    "nickName": np.nan,
    "honorificPrefix": np.nan,
    "honorificSuffix": np.nan,
}

donald_json2 = {
    "id": np.nan,
    "givenName": "President",
    "familyName": "Trump",
    "unaccentedGivenName": "President",
    "unaccentedFamilyName": "Trump",
    "birthYear": 1946,
    "deathYear": np.nan,
    "congresses": [
        {
            "position": "President",
            "congressNumber": np.nan,
            "stateName": np.nan,
            "parties": ["Republican"],
        }
    ],
    "middleName": "John",
    "unaccentedMiddleName": "John",
    "nickName": np.nan,
    "honorificPrefix": np.nan,
    "honorificSuffix": np.nan,
}

donald_json3 = {
    "id": np.nan,
    "givenName": "President Donald",
    "familyName": "Trump",
    "unaccentedGivenName": "President Donald",
    "unaccentedFamilyName": "Trump",
    "birthYear": 1946,
    "deathYear": np.nan,
    "congresses": [
        {
            "position": "President",
            "congressNumber": np.nan,
            "stateName": np.nan,
            "parties": ["Republican"],
        }
    ],
    "middleName": "John",
    "unaccentedMiddleName": "John",
    "nickName": np.nan,
    "honorificPrefix": np.nan,
    "honorificSuffix": np.nan,
}

politicians_df = politicians_df.append(
    pd.DataFrame([donald_json1, donald_json2, donald_json3]), ignore_index=True
)

# %%
politicians_df.tail(3)

# %%
# Export new df to json
politicians_df.to_json(os.path.join(RESOURCES_PATH, "new_congress_biolist.json"))

# %%
politicians_df["fullName"] = politicians_df["givenName"] + " " + politicians_df["familyName"]
politicians_df["fullName"] = politicians_df["fullName"].str.lower()

congress_members = politicians_df["fullName"].tolist()  # redefined here for clarity

def extract_subset(orig_df: pd.DataFrame, multiproc=False) -> pd.DataFrame:
    """
    This function extracts the quotes of speakers that are in the congress list.

    It returns the number of extracted quotes and the extracted dataframe.
    """

    if multiproc:
        orig_df["subset"] = orig_df["speaker"].parallel_apply(
            lambda x: pd.Series(x.lower()).str.contains("|".join(congress_members))
        )
    else:
        orig_df["subset"] = orig_df["speaker"].progress_apply(
            lambda x: pd.Series(x.lower()).str.contains("|".join(congress_members))
        )

    return orig_df["subset"].sum(), orig_df[orig_df["subset"] == True]

# %%
# 10% subset
quotes_2020_00 = quotes_2020_00.sample(int(0.1*len(quotes_2020_00)))

# %%
# Testing multiprocessing for extraction
subset_count, subset_2020 = extract_subset(quotes_2020_00)
subset_count

# %%
subset_2020["speaker"].value_counts()

# %%
# Goal is to do a pipeline to automatically extract quotes for a quotes dataset
# The datasets were already loaded from the json.bz2 format and converted to .pkl in `data/pkl`

# Get the names
quotes_datasets = [os.path.join("data", "pkl", f"quotes-20{i:02d}.pkl") for i in range(8, 21)]  

# For each dataset, extract the quotes from congress members
# and save the extracted quotes as pkl for easier handling
for i, dataset in enumerate(quotes_datasets, start=1):
    print(f"{i}/{len(quotes_datasets)} {dataset}:")
    try:
        complete_df = pd.read_pickle(dataset)  # Load dataset
    except FileNotFoundError:
        print(f"{dataset} not found, loading from .json.bz2")
        complete_df = load_df(dataset)

    _, subset_df = extract_subset(complete_df)
    subset_df.to_pickle(os.path.join("data", "pkl", f"extracted_{dataset}"))

# %%
year = 2008
files = get_pkl_year(year)

# Extract the quotes of interest of each chunk
all_extracted = []
for file in files:
    df = pd.read_pickle(os.path.join(PKL_PATH, file))
    _, subset_df = extract_subset(df)
    all_extracted.append(subset_df)

# Merge them into a new df
df_extracted = pd.concat(all_extracted)

# Save the df as pkl
pkl_name = f"extracted-quotes-{year}.pkl"
df_extracted.to_pickle(os.path.join(PKL_PATH, pkl_name))

# %%
df2_extracted = pd.read_pickle(os.path.join(PKL_PATH, "extracted-quotes-2016.pkl"))
df2 = pd.read_pickle(os.path.join(PKL_PATH, "2016", "quotes-2016-26.pkl"))
df2 = df2.sample(100_000)

# %%
length, df2_extracted2 = extract_subset(df2, multiproc=True)

# %%
length

# %% [markdown]
# ## Load datasets

# %%
# Mac/Linux
# Load the main dataset
# df = pd.read_pickle("data/pkl/extracted-quotes-2018.pkl")

# Windows
with open("data/pkl/extracted-quotes-2018.pkl", "rb") as fh:
   data = pickle.load(fh)
# Out:
# Requirement already satisfied: pickle5 in c:\users\rened\anaconda3\lib\site-packages (0.0.11)

# %%
data
# Out:
#                     quoteID  \
# 16000014  2018-05-11-081190
# 16000115  2018-10-16-075122
# 16000162  2018-05-25-071034
# 16000292  2018-09-14-074686
# 16000312  2018-09-05-072584
# ...                     ...
# 23999680  2018-05-29-017492
# 23999706  2018-12-14-017624
# 23999786  2018-03-30-019552
# 23999851  2018-10-25-024068
# 23999984  2018-03-26-024127
#
#                                                   quotation  \
# 16000014  Mood remained upbeat despite rising crude oil ...
# 16000115  My favourite image changes quiet regularly but...
# 16000162  My philosophy is very simple: when you see som...
# 16000292              no program, no speeches, no politics.
# 16000312                      nor would it be contemplated.
# ...                                                     ...
# 23999680  Donald Trump Jr. retweeted Roseanne Barr's rac...
# 23999706                            down to five finalists.
# 23999786  endorsed the crown prince's high profile antic...
# 23999851  Eventually we'll get past it; we'll elect diff...
# 23999984  Farmers were having to transport on the roads ...
#
#                          speaker  \
# 16000014  President Donald Trump
# 16000115             David Price
# 16000162              John Lewis
# 16000292              Lois Capps
# 16000312  President Donald Trump
# ...                          ...
# 23999680            Donald Trump
# 23999706         President Trump
# 23999786         President Trump
# 23999851         Collin Peterson
# 23999984             James Comer
#
#                                                        qids  \
# 16000014                                           [Q22686]
# 16000115  [Q1176177, Q16063598, Q20804677, Q20973688, Q3...
# 16000162  [Q14945660, Q16227288, Q18922034, Q19565272, Q...
# 16000292                                          [Q459693]
# 16000312                                           [Q22686]
# ...                                                     ...
# 23999680                                [Q22686, Q27947481]
# 23999706                                           [Q22686]
# 23999786                                           [Q22686]
# 23999851                                          [Q434458]
# 23999984                                         [Q6131602]
#
#                         date  numOccurrences  \
# 16000014 2018-05-11 00:00:00               4
# 16000115 2018-10-16 20:21:26               1
# 16000162 2018-05-25 10:24:00               1
# 16000292 2018-09-14 07:02:33               1
# 16000312 2018-09-05 20:08:11               3
# ...                      ...             ...
# 23999680 2018-05-29 23:15:20               1
# 23999706 2018-12-14 20:30:10               1
# 23999786 2018-03-30 01:28:31               4
# 23999851 2018-10-25 22:50:19               1
# 23999984 2018-03-26 21:18:48               1
#
#                                                      probas  \
# 16000014  [[President Donald Trump, 0.5749], [None, 0.29...
# 16000115  [[David Price, 0.9163], [None, 0.0624], [Thier...
# 16000162             [[John Lewis, 0.6994], [None, 0.3006]]
# 16000292             [[Lois Capps, 0.8035], [None, 0.1965]]
# 16000312  [[President Donald Trump, 0.8022], [None, 0.17...
# ...                                                     ...
# 23999680  [[Donald Trump, 0.62], [None, 0.279], [Roseann...
# 23999706  [[President Trump, 0.5204], [None, 0.4372], [M...
# 23999786  [[President Trump, 0.6701], [None, 0.3166], [D...
# 23999851        [[Collin Peterson, 0.7925], [None, 0.2075]]
# 23999984  [[James Comer, 0.7394], [None, 0.2268], [David...
#
#                                                        urls phase  subset
# 16000014  [http://www.canindia.com/global-cues-better-q4...     E    True
# 16000115  [http://dailycannon.com/2018/10/exclusive-davi...     E    True
# 16000162  [https://www.inc.com/emily-canal/john-lewis-co...     E    True
# 16000292  [http://www.independent.com/news/2018/sep/14/b...     E    True
# 16000312  [http://europe.newsweek.com/trump-says-did-not...     E    True
# ...                                                     ...   ...     ...
# 23999680  [https://www.washingtonexaminer.com/news/donal...     E    True
# 23999706  [https://www.theatlantic.com/politics/archive/...     E    True
# 23999786  [http://mobile.nytimes.com/2018/03/29/business...     E    True
# 23999851  [http://dl-online.com/news/4519529-dl-students...     E    True
# 23999984  [http://www.kfvs12.com/story/37812224/3-heartl...     E    True
#
# [721005 rows x 10 columns]

# %%
# Load the dataset with additional info abbout politicians 
df_politicians = pd.io.json.read_json("data/resources/new_congress_biolist.json")

# %% [markdown]
# ## Work on df_politicians table

# %%
# Extract from congresses column relevant infor (position, state, parties)
def extract_congress_information(row):
    information = pd.json_normalize(row["congresses"]).sort_values("congressNumber").tail(1).loc[:, ["position","stateName","parties"]]

    row["position"] = information.loc[:, "position"].values[0]
    row["stateName"] = information.loc[:, "stateName"].values[0]
    row["parties"] = information.loc[:, "parties"].values[0]
    return row

df_politicians = df_politicians.apply(extract_congress_information, axis=1)

# %%
# The value in column parties is a list, we want to select the last past party from the list
def getLastValue(aList):
    return aList[-1]

df_politicians["parties"] = df_politicians["parties"].apply(getLastValue)

# %%
# Create new column speaker (full name of the politician)
df_politicians['speaker'] = df_politicians['givenName'] + " " + df_politicians['familyName']

# Have the speaker's full names in the same size 
df_politicians["speaker"] = df_politicians["speaker"].str.lower()

# In lower case also in the quotes dataset
df["speaker"] = df["speaker"].str.lower()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'speaker'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3750         try:
# -> 3751             loc = self._info_axis.get_loc(key)
#    3752         except KeyError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#
# KeyError: 'speaker'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-95400d384a36> in <module>
#       1 # Create new column speaker (full name of the politician)
# ----> 2 df_politicians['speaker'] = df_politicians['givenName'] + " " + df_politicians['familyName']
#       3
#       4 # Have the speaker's full names in the same size
#       5 df_politicians["speaker"] = df_politicians["speaker"].str.lower()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3795                     value = np.tile(value, (len(existing_piece.columns), 1)).T
#    3796
# -> 3797         self._set_item_mgr(key, value)
#    3798
#    3799     def _set_value(
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3752         except KeyError:
#    3753             # This item wasn't present, just insert at end
# -> 3754             self._mgr.insert(len(self._info_axis), key, value)
#    3755         else:
#    3756             self._iset_item_mgr(loc, value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value)
#    1174         if loc == self.blklocs.shape[0]:
#    1175             # np.append is a lot faster, let's use it if we can.
# -> 1176             self._blklocs = np.append(self._blklocs, 0)
#    1177             self._blknos = np.append(self._blknos, len(self.blocks))
#    1178         else:
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in append(arr, values, axis)
#    4667         if arr.ndim != 1:
#    4668             arr = arr.ravel()
# -> 4669         values = ravel(values)
#    4670         axis = arr.ndim-1
#    4671     return concatenate((arr, values), axis=axis)
#
# <__array_function__ internals> in ravel(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in ravel(a, order)
#    1804
#    1805     """
# -> 1806     if isinstance(a, np.matrix):
#    1807         return asarray(a).ravel(order=order)
#    1808     else:
#
# AttributeError: module 'numpy' has no attribute 'matrix'

# %%
# Check for full name duplicates
# I propose to delete those as they may be in different parties and we will not which one is talking
df_politicians['speaker'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'speaker'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-155c97460be0> in <module>
#       1 # Check for full name duplicates
#       2 # I propose to delete those as they may be in different parties and we will not which one is talking
# ----> 3 df_politicians['speaker'].value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'speaker'

# %%
# We drop duplicates by speaker's full name
df_politicians = df_politicians.drop_duplicates(subset=['speaker'])

# %% [markdown]
# ## Merge the quotes with info about speakers

# %%
# Merge quotes to speaker's info
data = pd.merge(df, df_politicians, on='speaker', how='outer') # we merged the dataset

# %%
# Subsets by parties 
subset_democrats = data[data['parties'] == "Democrat"]
subset_republicans = data[data['parties'] == "Republican"]

# %% [markdown]
# ## Naive model: select quotes that talk about the opponent party

# %%
# Get the list of Republicans and Democrats
names_democrats = df_politicians[df_politicians['parties'] == 'Democrat']["speaker"].tolist()
names_republicans = df_politicians[df_politicians['parties'] == 'Republican']["speaker"].tolist()

# %%
# Have all quotes in lowercase
data["quotation"] = data["quotation"].str.lower()
subset_democrats["quotation"] = subset_democrats["quotation"].str.lower()
subset_republicans["quotation"] = subset_republicans["quotation"].str.lower()

# %%
# Drop rows with those who don't have any quotes
data = data.dropna(subset=['quotation'])
subset_democrats = subset_democrats.dropna(subset=['quotation'])
subset_republicans = subset_republicans.dropna(subset=['quotation'])

# %%
# Create full lists 
list_rep = names_republicans + ['republican', 'republicans']
pattern_list_rep = '|'.join(list_rep)

list_dem = names_democrats + ['democrat', 'democrats']
pattern_list_dem = '|'.join(list_dem)

# %%
# Subset of quotes said by democrats about republicans
demo_quotes_abt_rep = subset_democrats[subset_democrats['quotation'].str.contains(pattern_list_rep)]

# %%
# Subset of quotes said by democrats about democrats
rep_quotes_abt_demo = subset_republicans[subset_republicans['quotation'].str.contains(pattern_list_dem)]

# %% [markdown]
# ## Sentiment analysis of the quotes

# %%
import nltk
# nltk.download()
nltk.download('vader_lexicon')

from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
# Function that get the sentiment of each quote
def get_sentiment(row):   
    row['NLTK score'] = sia.polarity_scores(row['quotation'])
    return row

# %%
# Apply function on the subsets - for republicans and democrats
demo_quotes_abt_rep = demo_quotes_abt_rep.apply(get_sentiment, axis=1)
rep_quotes_abt_demo = rep_quotes_abt_demo.apply(get_sentiment, axis=1)

# %%
# Split in columns to get values 
# Democrats about republicans 
demo_quotes_abt_rep = pd.concat([demo_quotes_abt_rep, demo_quotes_abt_rep['NLTK score'].apply(pd.Series)], axis=1)

# Republicans about democrats
rep_quotes_abt_demo = pd.concat([rep_quotes_abt_demo, rep_quotes_abt_demo['NLTK score'].apply(pd.Series)], axis=1)

# %% [markdown]
# ## EDA:  We have 2 datasets that we want to analyze

# %% [markdown]
# The problem is that we have too quotes classified as neutral.
# We should read about SentimentIntensityAnalyzer as we may need to preprocess before, or use a different sentiment predictor.
# Another thing: may be we should appply the analyzer before even lower casing the sentences (because maybe some excitement/anger can be in upper case)
# Something to think about.
# https://www.analyticsvidhya.com/blog/2021/01/sentiment-analysis-vader-or-textblob/

# %% [markdown]
# #### Republicans about democrats

# %%
rep_quotes_abt_demo.head(1)

# %%
plt.hist(rep_quotes_abt_demo['neg'], alpha=0.5);
plt.hist(rep_quotes_abt_demo['pos'], alpha=0.5);
plt.hist(rep_quotes_abt_demo['neu'], alpha=0.5);
labels = ['neg','pos', 'neu'];
plt.title('Distribution of sentiment');
plt.legend(labels);

# %% [markdown]
# ### 3. Quotes extraction

# %% [markdown]
# can't use congress members list directly, to extract quotes by author, need them aliases

# %%
a = []
for i in range(len(congress_members)) :
    a.append(congress_members[i][0])
a
df2 = df[df["speaker"].isin(a)]
df2
# None because for example, Hillary Clinton is written 'Hillary Rodham Clinton'

### Works like this
#b = ['James Fisher', 'John Updike', 'Hillary Clinton']
#df2 = df[df["speaker"].isin(b)]
#df2
# Out:
# Empty DataFrame
# Columns: [quoteID, quotation, speaker, date, numOccurrences, phase, Transformers_score, NLTK_score]
# Index: []

# %%
df_speaker_attributes["aliases"]
df_speakers = df_speaker_attributes["aliases"].tolist()
df_speakers
# Out:
# [array(['Washington', 'President Washington', 'G. Washington',
#         'Father of the United States', 'The American Fabius'], dtype=object),
#  array(['Douglas Noel Adams', 'Douglas Noël Adams', 'Douglas N. Adams'],
#        dtype=object),
#  array(['Paul Marie Ghislain Otlet', 'Paul Marie Otlet'], dtype=object),
#  array(['George Walker Bush', 'Bush Jr.', 'Dubya', 'GWB', 'Bush 43',
#         'President George W. Bush', 'George Bush', 'President Bush',
#         'Bush', 'Bush, George W.'], dtype=object),
#  array(['Velázquez', 'Diego Rodríguez de Silva y Velázquez',
#         'Diego Rodriguez de Silva y Velázquez', 'Diego de Silva Velàzquez',
#         'Diego De Velázquez y Silva',
#         'Diego Rodríguez de Silva y Velasquier', 'Diego Velasques',
#         'Diego Rodríguez de Silva y Velasquiz', 'Diego Velásquez',
#         'Diego Valesquez', 'Diego Velasquex', 'Diego Velázquez y Silva',
#         'Diego de Silva Velázquez', 'Diego de Silva Velazquez',
#         'Diego Villasco', 'Diego de Velázquez y Silva',
#         'Diego de Silva Velaskes', 'Diego Velasque',
#         'Diego de Silva y Velasquez',
#         'Diego Rodriguez de Silva y Velazquez', 'Diego Velázquez de Silva',
#         'Diego Velasco Spagnolo', 'Diego Valaquez', 'Diego Valasquez',
#         'Don Diego Velasquez', 'Diego Belazquez', 'Diego Velascus',
#         'Diego Rodriguez De Silva Y Velazquez', 'Diego Valasques',
#         'Diego Velazquez', 'Diego de Silva', 'Diego Velasquez de Silva',
#         'Diego Rodríguez de Silva y Velazquez',
#         'Diego de Silva y Velázquez', 'Diego Velasmo',
#         'Diego Rodriguez de Silva y Velasquez', 'Diego Velasco',
#         'Diego Velasquez y Silva', 'Diego Velarques', 'Diego De Silva',
#         'Diego Rodriquez de Silva y Velazquez', 'Diego Velasquez',
#         'Diego De Silva Velaskes', 'Diego de Velázquez de Silva',
#         'Diego Rodríguez de Silva y Belasquez',
#         'Diego Rodriguez de Silva y Velásquez',
#         'Diego Rodriguez Velásquez',
#         'Diego Rodríguez de Silva y Velásquez',
#         'Diego Rodríguez De Silva Y Velázquez', 'Velazquez',
#         'Diego Rodriguez de Silva Velazquez', 'Diego De Velazquez y Silva',
#         'Diego Rodriguez de Silva y Velasquier',
#         'Diego Rodriguez de Silva y Velasquiz', 'Diego Velazquez y Silva',
#         'Diego Velazquez de Silva', 'Diego de Silva y Velazquez',
#         'Diego de Velazquez de Silva',
#         'Diego Rodriguez de Silva y Belasquez',
#         'Diego Rodriguez Velasquez', 'Diego Velasco spagnolo',
#         'Diégo Vélasquez', 'Velasqez', 'diego velazquez de silva',
#         'd. r. de silva y velasquez', 'Don Diego Valasques', 'Velasquex',
#         'Velasquez', 'Velasques', 'Velasquer', 'Valaquez',
#         'Diégo-Vélasquez', 'Dom Diego Velasquès', 'Valesquez',
#         'c. diego velasquez de silva', 'Vélaquez', 'Valasques',
#         'Valasquez', 'Velasquéz', 'Flasques', 'Velasquez de Silva',
#         'Diego de Velazquez', 'Belazquez', 'Diego Velaschi', 'Velasque',
#         'Diego Velasquèz', 'Lavasquez', 'D. Velasquez', 'Vélasquès',
#         'D. Diego Velasquez', 'D. Velaquez', 'Diego Vellasquez',
#         'de Silva Diego Velasquez', 'Velascus',
#         'Don Diego Velasquez de Silva', 'Velasquiz', 'Velasquesz',
#         'Vilasquez', 'Velasmo', 'Velasquier', 'Velarquez', 'Velarques',
#         'Dom Diego de Velasques', 'diego di silva y velasquez',
#         'Don Diégo Velasquez', 'Diego Velasquez Spagnuolo',
#         'Cavalier Velasquès', 'Vallascio', 'Diego Valaschi',
#         'Diègo Rado. Velazquez', 'Velasco', 'Diego Vellasquetz',
#         'diego velasquez de silva', 'Don Velasquez', 'Don Diego Velazquez',
#         'Belasquez', 'd. r. velazquez', 'Diego de Velasco',
#         'D. Diego Velasquès', 'Diego Rodríguez de Silva Velázquez'],
#        dtype=object),
#  array(['Augusto Pinochet Ugarte', 'Augusto José Ramón Pinochet Ugarte'],
#        dtype=object),
#  array(['Baudelaire', 'Charles Pierre Baudelaire-Dufaÿs',
#         'Charles Pierre Baudelaire', 'Charles Baudelaire'], dtype=object),
#  array(['Mikołaj Kopernik', 'Nikolaus Kopernikus', 'Copernicus',
#         'Niklas Koppernigk'], dtype=object),
#  array(['Neil Percival Young', 'Shakey', 'Godfather of Grunge',
#         'Neil Percival Kenneth Robert Ragland Young'], dtype=object),
#  None,
#  None,
#  array(['Gabriel González Videla', 'Gabriel Gonzales Videla',
#         'Gabriel Gonzalez Videla'], dtype=object),
#  array(['Andrei Arsenyevich Tarkovsky', 'Andrej Tarkovskij',
#         'Andrei Tarkovski', 'Andrej Tarkovszkij',
#         'And. Arsenʹevich Tarkovskiĭ', 'Andrey Arsenyevich Tarkovsky',
#         'Andreĭ Arsenʹevich Tarkovskĭi', 'Andrei Tarkovskij',
#         'Andreĭ Arsenévich Tarkovskiĭ', 'Andrey Tarkovsky',
#         "Andreĭ Arsen'evich Tarkovskiĭ", 'Andrej Tarkowskij',
#         "Andreiĭ Arsen'evich Tarkovskiĭ", "Andrei Arsen'evich Tarkovskii"],
#        dtype=object),
#  array(['Platon', 'Aristocles'], dtype=object),
#  array(['Mary Louise Streep', 'Meryl Louise Streep', 'Streep, Meryl'],
#        dtype=object),
#  array(['Donald Franciszek Tusk'], dtype=object),
#  array(['Andrei D. Sakharov'], dtype=object),
#  None,
#  array(['Namo', 'Modi', 'Narendra Bhai', 'Narendra Damodardas Modi',
#         'Narendrabhai Damodardas Modi', 'Narendrabhai'], dtype=object),
#  array(['Indira Nehru', 'Indira Priyadarshini Gandhi',
#         'Indira Priyadarshini Nehru', 'Indira Ghandi'], dtype=object),
#  array(['Louis Hector Berlioz'], dtype=object),
#  None,
#  array(['Ban Kimoon', 'Ban Ki Moon'], dtype=object),
#  array(['Kofi Atta Annan', 'Annan', 'Kofi A. Annan'], dtype=object),
#  array(['Leonard Norman Cohen', 'Jikan'], dtype=object),
#  array(['Usāmah bin Muḥammad bin ‘Awaḍ bin Lādin', 'Usama bin Laden',
#         'Osama bin Mohammed bin Awad bin Laden'], dtype=object),
#  array(['Friedrich August von Hayek', 'Friedrich von Hayek',
#         'Friedrich A. von Hayek', 'Friedrich A. Von Hayek',
#         'F. A. von Hayek', 'Friedrich August Von Hayek', 'Hayek',
#         'F. A. Hayek'], dtype=object),
#  array(['Jose Joaquin Prieto', 'Joaquín Prieto'], dtype=object),
#  None,
#  array(['Marcus Salvius Otho'], dtype=object),
#  array(['Titus Flavius Vespasianus', 'Emperor of Rome Titus',
#         'Titus Flavius Sabinus Vespasianus', 'Titus Vespasianus Augustus',
#         'Emperor of Rome Titus Flavius Vespasianus'], dtype=object),
#  array(['Wilhelm Richard Wagner', 'Wagner'], dtype=object),
#  array(['Ramesses', 'Pa-ra-mes-su', 'Menpehtyre', 'Rameses'], dtype=object),
#  None,
#  None,
#  array(['Abel Kiprop Mutai'], dtype=object),
#  array(['Erick Bernabé Barrondo García', 'Erick Bernabe Barrondo Garcia'],
#        dtype=object),
#  array(['Robert "Robbie" Karl Grabarz'], dtype=object),
#  None,
#  array(['Ashton James Eaton'], dtype=object),
#  array(['Emperor of Rome Gordianus III', 'Emperor of Rome Gordian III',
#         'Marcus Antonius Gordianus', 'Marcus Antonius Gordianus Pius',
#         'Gordianus III'], dtype=object),
#  array(['Olivier Jonathan Giroud'], dtype=object),
#  array(["Yann Gérard M'Vila"], dtype=object),
#  array(['Sidney Rodrigue Noukpo Govou'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Jacques René Chirac'], dtype=object),
#  array(['Georges Jean Raymond Pompidou'], dtype=object),
#  array(['Michel Gérard Joseph Colucci', 'Michel Gerard Joseph Colucci'],
#        dtype=object),
#  array(['Ludwig Wilhelm Erhard'], dtype=object),
#  array(['Helmut Josef Michael Kohl', 'Kohl'], dtype=object),
#  array(['Richard Karl Freiherr von Weizsäcker'], dtype=object),
#  None,
#  array(['Frederick William Victor Albert of Prussia',
#         'Friedrich Wilhelm Viktor Albrecht von Preußen',
#         'Friedrich Wilhelm Emperor William II',
#         'Wilhelm II, German Emperor', 'German Emperor Wilhelm II',
#         'Wilhelm II.', 'William II', 'Wilhelm II of Germany',
#         'Friedrich Wilhelm Viktor Albert von Hohenzollern',
#         'Kaiser Wilhelm II'], dtype=object),
#  None,
#  None,
#  array(['Elisha Meredith', 'Elisha Edward Meredith'], dtype=object),
#  array(['Dr. H. Clifford', 'Dr. Hubert John Clifford'], dtype=object),
#  None,
#  array(['Anne Sophie Mutter'], dtype=object),
#  array(['Franciszek Karpinski', 'Franciszek Karpiński'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['Ramses IX', 'Amon-her-khepshef Khaemwaset'], dtype=object),
#  array(['Louis Andrieux', 'Albert de Routisie', 'Arnaud de Saint Romain',
#         'François la Colère'], dtype=object),
#  array(['George A. Bournoutian'], dtype=object),
#  array(['Michel François Platini'], dtype=object),
#  array(['Ademar de Chabannes'], dtype=object),
#  array(['Thomas Matthew DeLonge', 'Thomas DeLonge', 'Ava DeLonge',
#         'Tom delong', 'Tom Matthew DeLonge', 'Boomer', 'Jonas DeLonge',
#         'Big Oily Men', 'Tom Delonge Signature Guitar',
#         'Thomas Matthew Delonge Jr.'], dtype=object),
#  None,
#  array(['Jonny Abrahams', 'Johnny Abrahams', 'Jon Avery Abrahams'],
#        dtype=object),
#  array(['Theopompus of Chios'], dtype=object),
#  None,
#  array(['Emily Elizabeth Dickinson', 'Ai-mi-li Ti-chin-sen',
#         'Emilia Dickinson', 'Emily Dickinson'], dtype=object),
#  array(['Stefanie Fabienne Heinzmann'], dtype=object),
#  array(['Ana faris', 'Anna Farris', 'Anna Kay Faris'], dtype=object),
#  array(['Willard Mitt Romney', 'Pierre Delecto'], dtype=object),
#  None,
#  array(['Princess Mary Stewart of Scotland',
#         'Mary Stewart, Countess of Arran', 'Mary Stewart von Schottland'],
#        dtype=object),
#  None,
#  array(['Claud Debussy', 'Debussy', 'Claude Achille Debussy',
#         'Achille Claude Debussy', 'C. Debussy', 'Claude-Achille Debussy',
#         'Achille-Claude', 'Achille-Claude Debussy'], dtype=object),
#  array(['Charles II de Croy', 'Charles I',
#         'Charles de Croy, Prince de Chimay'], dtype=object),
#  array(['Junior Cesar Moreira da Cunha', 'Junior Cesar Moreira Da Cunha'],
#        dtype=object),
#  None,
#  array(['Roy Frederick Budd'], dtype=object),
#  array(['Sweijs', 'Anthony Ahasuerus Hendrik Sweijs'], dtype=object),
#  None,
#  None,
#  array(['William Douglas Duke of Hamilton', 'William Douglas-Hamilton',
#         'William Douglas', 'Lord William Douglas', 'William Hamilton',
#         '3rd Duke of Hamilton',
#         'William Douglas-Hamilton, Duke of Hamilton'], dtype=object),
#  None,
#  array(['Wanyan Dan'], dtype=object),
#  array(['Wanyan Liang'], dtype=object),
#  None,
#  array(['Gualterus de Castellione', 'Gualterus de Insula',
#         'Walterus ab Insulis', 'Gualterus de Castiglione',
#         'Galterus de Castellione', 'Walter of Chatillon'], dtype=object),
#  array(['François-Edouard Picot', 'Francois Eduard Picot',
#         'François Eduard Picot', 'François Edouard Picot',
#         'Francois Edouard Picot', 'Picot'], dtype=object),
#  None,
#  None,
#  array(['B. Sket', 'Sket'], dtype=object),
#  None,
#  None,
#  array(['Maria de Ventedorn'], dtype=object),
#  None,
#  array(['David Robert Jones', 'David Jones', 'Bowie', 'Davy Jones',
#         'Thin White Duke', 'Halloween Jack'], dtype=object),
#  None,
#  array(['Medoro Coghetti', 'Medoro Coghetto'], dtype=object),
#  array(['Andreas Angeli Francisci', 'Andrea Delserto', 'Andrea del Sardi',
#         "Andrea d'Agnolo del Sarto", 'Andre de Sartre', 'Andr. del Sarto',
#         "Andrea d'Agnolo", 'Andrea del Sarto Fiorentino',
#         'Andrea de Sarto', 'Andrea del Sarti', 'Andrea del Sarte',
#         'Andrew del Sarto', 'Andrea DelSarto', 'André del Sarto',
#         "Andrea D'Agnolo", 'André del Sarte', 'Andrea Sarto',
#         'Andrea Vannucci', 'Andrea Del Sarto', 'Andrea del Sartto',
#         "Andrea d'Agnolo di Francesco", 'Andres del Sartto',
#         'Andrea di Sarto', 'Andrea Delsarto', 'Andrea del Salto',
#         'Andria del Sarto', "Andrea d'Angiolo", 'Andrea Vannucchi',
#         "Andrea, del Sarto d'Agnolo", "Andrea d' Agnolo",
#         'Andre del Sarto', 'Andre del Sarte', 'Andrea del Certa',
#         'andree del sarto', 'A del Sarte', 'Adrea del Sarto',
#         'And: del Sarto', 'A. Del Sarto',
#         'Andrea Vannucci detto del Sarto', 'Adrian del Sarto',
#         'Andrea el sarto', 'Called, Andrea del Sarto Andrea Vannucci',
#         'And. Delsarte', 'And. Delsarto',
#         'Vanucchi Andrea detto Dal Sarto',
#         'andrea di agnolo gen. del sarto', 'Andrea Sarti',
#         'Ande. del Sarto', 'Andr Del Sarto', 'André Delsartes',
#         'Anda. dl Sarto', 'Andrea Vanucchi', 'sarto andrea del',
#         'dit del Sarto Vannucci', 'André del Serto',
#         'or Andrea Venucchi Andrea del Sarto', 'Sarto fiorentino',
#         'A. del Sarte', 'André Del-Sarte', 'Andrea del Sacho',
#         'A. del Sarto', 'André Delsart',
#         'Andrea Vannucchi detto Andrea del Sarto', 'andrea del sardo',
#         'A.D. Sarto', 'El Sarto', 'Del Sarto', 'And. del Sarto',
#         "andrea d'angelo del sarto", 'andrea del sarto', 'sarto a. del',
#         'A. Vanucchi or del Sarto', 'andrea del Sacco', 'And.a Sarto',
#         'Andreas Delsarto', 'Andrés del Sarto', 'Andreo del Sarte',
#         'Sarti', 'Sarto', 'And.a del Sarti', 'And. Del. Sarto',
#         'And.a del Sarto', 'Called Andrea del Sarto Andrea Vannucci',
#         'A. del Serto', 'Adelsarto', 'Andrea del Sarta', 'Andres el sarto',
#         'genannt del Sarto Andr. Vannucchi', 'A. D. Sarto',
#         'André del Sart', 'André Delsaltre', 'André del Sartre',
#         'A. di Sarto', 'Andrea del Serto', 'André Delsate', 'A Del Sarto',
#         'Andres del Sarto', 'Sardo', 'And. del Sarte', 'Anda. del Sarto',
#         'André Del-Sarto', 'A: del Sarto', 'Andrea Delsart',
#         'André Delzatte', 'Andr. del Sardo', 'André Delfart',
#         'A. de Sarto', 'Delserto', 'Andre del Sarti',
#         'Eigentl. Andrea Angeli Andrea Del Sarto',
#         'Andrea Vannini detto del Sarto', 'Andrea', "André d'Elsarte",
#         'Andreas del Sarto', 'André Delsarto', 'André Delsarte',
#         'Andrea dl Sarto', 'A. Delsarto', 'André del Salte',
#         'An. del Sarto', 'And. del Sorto', 'A. Delsarte',
#         'Andréa del Sarto'], dtype=object),
#  array(['Dürer', 'Albert Duur', 'Albrecht Türer', 'Albrecht Duerer',
#         'Alber Dure', 'Albert Duer', 'Alberto Duro Tedesco', 'Alberdure',
#         'Albrecht Dyûrâ', 'Alberto Duredo', 'Albrekht Diurer',
#         'Alberto Duri', 'Alverto Dureño', 'Alberduer', 'Alberto Dura',
#         'Albert Dure', 'Dure Albert', 'Albert Dur', 'Albert Durer',
#         'Alberto di Dura', 'Albrecht Durer', 'Alberto Durero',
#         'Alberto Duro', 'Albrecht Dyura', 'Alcberdure', 'Alberto de Dura',
#         'A. Duur', 'A.B. Duur', 'Alverto dureño', 'alberto',
#         'Fiammingo Alberto Dureto', 'Albertto duro', 'Albert Dürer',
#         'Durer. Albert', 'Alverto durero', 'Duerer', 'A. Duurer',
#         'Alberdurer', 'Alberdures', 'Albero Duro', 'alburo', 'A: Durer',
#         'Albertus Durerus', 'Albertus Dürer', 'Albr. Dürrer',
#         'Albert-Durr', 'Albrecht Düren', 'de Nuremberg Albert Durer',
#         'Albertdurer', 'A. Dürre', 'Alberto Vrero', 'Albert Duerer',
#         'Albrecht Durrer', 'Alberduur', 'Alb. Durrer', 'durer albrecht',
#         'Durer', 'Albr. Dürer', 'Aelbregt Duur', 'Aldrecht Durer',
#         'Alber-durer', 'Albert Dura', 'Albr. Durer', 'Albert-Duver',
#         'Albrecht Duren', 'Albert Duyrer', 'Alb. Durer', 'Al. Durer',
#         'A. Durer', 'Albert van Dürer', 'A Durer', 'A. Dürer',
#         'Albrecht Dürrer', 'Alb. Duro', 'Alb. Dürer', 'Albert Daret',
#         'Aelbert Duur', 'A. Durerus', 'Alverto', 'A. Duri', 'A. Duru',
#         'Alverto duro', 'Alberto Dureroe', 'Albert-dur', 'A. Durre',
#         'Alberto Durer', 'Albert-Durer', 'A. Dürrer', 'Dürer Albr.',
#         'Albert', 'Albert DÜren', 'Alborduer', 'Albregt Duur',
#         'Alber Durer', 'Alba Dure', 'Albrecht Dyrer', 'Albert Dúr',
#         'Alb. Düren', 'Albert Drurer', 'a. d.', 'Albertto', 'Durier',
#         'Alberto Dürer', 'Albrehts Dīrers', 'Albertus Durer',
#         'Alberto Dürero', 'Albrecht Djurer'], dtype=object),
#  array(['Hokusai', 'Hokusai Katsushika', 'Taito Katsushika',
#         'Hachiemon Miuraya', 'Taito', 'Raishin', 'Manji Rōjin', 'Tokimasa',
#         'Iitsu Katsushika', 'Hokusai Tokimasa', 'Zenhokusai', 'Tatsumasa',
#         'Manji', 'Pei-chai Ko-shih', 'Iitsu', 'Shunro', 'Katsushika Taito',
#         'Fusenkyo', 'Sorobeku'], dtype=object),
#  None,
#  array(['Antonello di Giovanni di Antonio', 'Antonello degli Antoni',
#         'An. Da Messina', 'Antonellus Massaneus', 'da Messina Antonio',
#         'Antonello di Giovanni degli Antonii', "Antonello d' Antonio",
#         'Antonio da Messina', 'da Messina Antonello',
#         'Antonello Da Messina', 'Antonello', 'Antonelli de Meseina',
#         'Ant. da Messine', 'Antonelli di Messina', 'Ant. de Messine',
#         'A. di Messina', 'Antonello di Messina', 'antonello von messina',
#         'Antonello de Messine', 'preésumé de Antonello Da Messina Antique',
#         'antonellus massaneus', 'Antonello ou Antoine de Messine',
#         'Antonella di Messina', 'Antonello de Messina'], dtype=object),
#  None,
#  array(['Conon de Bethune'], dtype=object),
#  array(['Guido di Pietro', 'Fra Giovanni da Fiesole',
#         'Fra Giovanni Angelico', 'Beato Angelico', 'Giovanni da Fiesole',
#         'Fra Beato Angelico', 'Guido di Piero da Mugello',
#         'Fra Giovanni Angelico da Fiesole',
#         'Fra Giovanni Da Fiesole Angelico',
#         'Fra Giovanni, da Fiesole Angelico', 'da Fiesole Giovanni',
#         'Guido di Piero da Mugello Angelico',
#         'Fra Giovanni da Fiesole Angelico', 'Giovanni Da Fiesole',
#         'di Piero Guido', 'Guido da Vicchio', 'Guido di Piero',
#         'fra Angelico', 'Giovanni Angelico', 'Beato Angelico da Fiesole',
#         'Angelico (fra)', 'Beato (Fra)', 'Giovanni (Fra)',
#         'Giovanni Angelico da Fiesole (Fra)', 'Guido di Pietro da Mugello',
#         'Guidolino di Pietro da Mugello', 'Fra Angelico da Fiesole',
#         'Beata Da Fiesole', 'Beata Angelica da Fiesole', 'B. Angelico',
#         'Beato Giovanni', 'B. Gio. Angelo da Fiesole',
#         'fra angelico. fiesole', 'Fiesole',
#         'Beato Gio: Angelico da Fiesole', 'Da Fiesolé',
#         'B. Angelico da Fiesole', 'Da Fiesole',
#         'Fra Giovanni da Fiesole gen. Fra Angelico', 'beato fra Angelico',
#         'Beato Gio: Angelico', 'Beato Gio. Angelo di Fiesole',
#         'don Giovanni Angelico', 'Beato Giov. Angelico',
#         'Beato Gio. Angelo da Fiesole',
#         'fra Giovanni da Fiesole domenicano',
#         'beato Giovanni Angelico domenicano',
#         'called Il Beato Angelico Fra. Giovanni da Fiesole',
#         'florentino Beato Juan'], dtype=object),
#  array(['Abū Nuwās al-Ḥasan ibn Hānī al-Ḥakamī', 'Abū Nuwās'], dtype=object),
#  array(['Matsuo Basho', 'Bashō', 'Bashô', 'Basho', 'Matsuo Bashou'],
#        dtype=object),
#  array(['Henri Philippe Benoni Omer Joseph Pétain', 'Marshal Pétain',
#         'Philippe Petain', 'Henri Philippe Benoni Omer Joseph Petain',
#         'Marshal Petain'], dtype=object),
#  array(['Tommaso di Ser Giovanni di Simone', 'Mazachcho', 'Mazzacio',
#         'Tommaso di Ser Giovanni di Mone Cassai', 'Massacio',
#         'Tommaso Di Giovanni Di Simone Guidi Masaccio',
#         'Tommaso di ser Giovanni di Mone Guidi', 'Tommaso Guidi Masaccio',
#         'Mesaccio', 'Tommaso di Giovanni di Simone Guidi', 'Massaccio',
#         'Tommaso Guidi', 'Tommaso Guido',
#         'Tommaso di Ser Giovanni di Mone',
#         'called Masaccio Tomaso Guidi da S. Giovanni',
#         'called da San Giovanni Thomaso Masaccio', 'Le Masaccio',
#         'Tomaso Masaccio', 'Florentin Thomas Masaccio', 'T. Maccio',
#         'Mazaccio', 'Thomaso Masaccio', 'Masalio'], dtype=object),
#  array(['Mao Tse-tung', 'Chairman Mao', 'Mao Ze Dong', 'Maozedong',
#         'Tse Toung Mao'], dtype=object),
#  array(['Mariya Sergeyevna Savinova'], dtype=object),
#  array(['Charles Edward Anderson Berry',
#         'Charles Edward Anderson Chuck Berry'], dtype=object),
#  array(['Curtius Rufus'], dtype=object),
#  array(['Hebe Maria Monteiro de Camargo Ravagnani'], dtype=object),
#  None,
#  array(['Catherine Ibargüen Mena'], dtype=object),
#  array(['Yevgeniya Nikolayevna Kolodko', 'Yevgieniya Kolodko'],
#        dtype=object),
#  array(['Barbora Spotakova'], dtype=object),
#  None,
#  array(['Kierkegaard', 'Søren Aabye Kierkegaard', 'Victor Eremita',
#         'Climacus', 'Anti-Climacus'], dtype=object),
#  None,
#  array(['Maria Salomea Skłodowska', 'M. Curie', 'Maria Skłodowska-Curie',
#         'Marie Curie-Sklodowska', 'Maria Skłodowska'], dtype=object),
#  array(['Simone-Lucie-Ernestine-Marie Bertrand de Beauvoir', 'Castor'],
#        dtype=object),
#  array(['Qin San Shi'], dtype=object),
#  array(['Liu Fuling', 'Zhao Di'], dtype=object),
#  None,
#  array(['Liu Xin'], dtype=object),
#  None,
#  array(['Prince of Huaiyang', 'Shenggong', 'Liu Xuan', 'Gengshi Emperor'],
#        dtype=object),
#  array(['Han Zhangdi', 'Suzong', 'Xiaozhang', 'Liu Da', 'Zhang Di',
#         'Su Zong'], dtype=object),
#  array(['Annette Elizabeth Salmeen'], dtype=object),
#  array(['Liu Bian', 'Hongnongwang', 'Shao Di', 'Liu Ban(2)'], dtype=object),
#  array(['Otto Heinrich Frank', 'Otto H. Frank'], dtype=object),
#  array(['Margot Betti Frank'], dtype=object),
#  array(['Trane', 'John William Coltrane', 'St. John Will-I-Am Coltrane'],
#        dtype=object),
#  array(['Sima Zhong', 'Hui Di', 'Zhengdu'], dtype=object),
#  array(['Sima Yui', 'Sima Rui', 'Jingwen'], dtype=object),
#  array(['Sima Yan', 'Xianzong', 'Xian Zong', 'Cheng Di', 'Shigen'],
#        dtype=object),
#  array(['Sima Dan', 'Xianzong', 'Xiao Zong', 'Mu Di', 'Pengzu'],
#        dtype=object),
#  array(['Kathryn E. Uhrich'], dtype=object),
#  array(['Li Dewang'], dtype=object),
#  array(['Dorothy Mary Hodgkin', 'Dorothy Mary Crowfoot',
#         'Dorothy Crowfoot', 'Dorothy Crowfoot Hodgkin'], dtype=object),
#  None,
#  None,
#  array(['Ogotai', 'Yuán Tàizōng', 'Tai Zong', 'Wokuotai', 'Ogedei'],
#        dtype=object),
#  array(['Elizabeth Jocelyn Feinler', 'Elizabeth Jake Feinler',
#         'Jake Feinler', 'Elizabeth Feinler'], dtype=object),
#  array(['Ernst Ingmar Bergman'], dtype=object),
#  array(['Sandy Lerner'], dtype=object),
#  None,
#  array(['Ilia di Saint-Ismael'], dtype=object),
#  array(['Borgognone', 'Bergognone', 'Ambrogio da Fossano Bergognone',
#         'Ambrogio di Stefano Bergognone da Fossano', 'Ambrogio Borgognone',
#         'Ambrogio di Stefano', 'Ambrogio da Fossano',
#         'Ambrogio Brecognono', 'Il Bergognone',
#         'Ambrogio di Stefano da Fossano', 'Ambrosius',
#         'Ambrogio Stefani da Fossano Bergognone', 'Ambrogio di Fossano',
#         'Ambrogio Stefani da Fossano Borgognone',
#         'Ambrogio da Fossano Borgognone', 'Ambrogio',
#         'Ambrosius Bergognone', 'Ambrogio da Fosano Bergognone',
#         'Ambrogio Stefani da Fossano, Il Bergognone', 'A. Borgognone',
#         'ambrogio di stefano borgognone'], dtype=object),
#  array(['Ivan the Great', 'Ivan the Terrible', 'Ivan IV'], dtype=object),
#  array(['Louis Antoine Pardaillan De Gondrin',
#         "Louis Antoine de Pardaillan de Gondrin, Duc d'Antin",
#         "Louis Antoine de Pardaillan de Gondrin d'Antin"], dtype=object),
#  None,
#  None,
#  array(['the Posthumous', 'John the Posthumous', 'Jean Ier le Posthume',
#         'Jean I'], dtype=object),
#  array(['Constantine I', 'Saint Constantine',
#         'Gaius Flavius Valerius Aurelius Constantinus',
#         'Flavius Valerius Aurelius Constantinus Augustus',
#         'Constantinus I', 'Constantine'], dtype=object),
#  array(['Peter I', 'Pyotr Alexeyevich Romanov', 'Pissed off Peter',
#         'Petr I Alekseevich', 'le Grand Pierre',
#         'Emperor of Russia Petr I Alekseevich', 'Pyotr Alekseyevich',
#         'Emperor of Russia Peter I', 'Petr Alekseevich Romanov',
#         'Emperor of Russia Peeter I', 'Piotr Wielki',
#         'Emperor of Russia Pierre I', 'Petru cel Mare',
#         'empereur de Russie Pierre I', 'Zar Peter I. Russland',
#         'Pyotr Velikiy', 'Pietro il Grande', 'Petro Büyük',
#         'Emperador de Rusia Pedro I'], dtype=object),
#  array(['Lorenzo Sciarpelloni', 'Lorenzo Barducci',
#         "Lorenzo d'Andrea d'Oderigo", 'Lorenzo da Crede',
#         'Lorenzo Di Credi', 'Lorenzo Credi', "Lorenzo D'Andrea D'Oderigo",
#         "Lorenzo d'Oderigo", 'Lorenzo Scarpelloni', 'Lor Credi',
#         'Lorenzo da crede', 'L. Credi', 'Lor. Credi', 'L. da Credi',
#         'L. de Credi', 'Lorenzo da Credi'], dtype=object),
#  array(['Taiding Di', 'Jinzong', 'Emperor Taiding of Yuan',
#         'Pouyuandaizhudi'], dtype=object),
#  array(['Asugiba', 'Beierzhijin Asujiba', 'Emperor Tianshun of Yuan',
#         'Arigabag', 'Asujiba'], dtype=object),
#  array(['Archimedes of Syracuse'], dtype=object),
#  None,
#  array(['Augustin Louis Cauchy', 'Augustin Cauchy', 'Cauchy'], dtype=object),
#  array(['Marc Decimo'], dtype=object),
#  array(['Varius Rufus'], dtype=object),
#  None,
#  None,
#  array(['Xingyuan Huangdi', 'Yesüder'], dtype=object),
#  None,
#  array(['Nicholas Willis'], dtype=object),
#  None,
#  None,
#  array(['Richard Kipkemboi Mateelong'], dtype=object),
#  None,
#  array(['Mulan Khan', 'Molon'], dtype=object),
#  array(['Tümen Jasaghtu Khan'], dtype=object),
#  array(['Girolamo Francesco Maria Mazzola', 'Francesco Mazzola',
#         'Parmigiano', 'Il Parmigianino', 'Francesco Mazzuoli',
#         'Francesco Massola', 'Mazzuoli Parmigiano', 'Parmegianino',
#         'Francesco Mazzuola', 'Francesco Mazzoli', 'Parmeggianino',
#         'François Mazzuoli', 'Palmegianino', 'Parmeggiano', 'Parmagiano',
#         'Le Parmesan', 'Girolamo Francesco Maria Mazzola Parmigiano',
#         'Francisco Mazzuoli', 'Il Parmigiano', 'Parmesan',
#         'Francesco Parmigianino', 'Francesco Mazzolino', 'Parmigiani',
#         'Girolamo Francesca Maria Mazzola', 'Parmegiano', 'Parmagianino',
#         'Mazzuoli Parmigianino', 'Girolamo Francesco Maria Mazzuoli',
#         'Girolamo Francesco Maria Mazzola Parmigianino', 'il Mazzolino',
#         'Parmesan Di-Masuoli', 'Permitiano', 'Permagiano',
#         'Francesco Mazzuola Genannt: IIs Parmigiano', 'Parmesanino',
#         'Mazzola Parmigiano', 'Parmens', 'Parmesano',
#         'Parmesan Di-Mazuoli', 'Parmezan',
#         'Francesco Mazzuoli, detto Parmeggiano', 'Permegano',
#         'gen. parmigianino Francesco mazzuola', 'Parmig.no',
#         'called Parmegiano Francis Mazzola', 'Permanginiani', 'Pamagiano',
#         'Parmeginano', 'Parenagrano', 'Barmisano',
#         'dit le Parmesan Mazzuoli', 'Francisco Mazzoli', 'Pamigiano',
#         'Permegianino', 'Parmeg.o', 'Parmigianino Francesco Mazzuola',
#         'F. M. Parmigiano', 'Permigiano', 'Le Parmissan', 'Parmegiani',
#         'Francesco Mazzuola gen. il Parmigiano',
#         'Francesco Mazzuola gen. Il Parmiggionino', 'Parmeggiani',
#         'Parmigeano', 'Parnegiano', 'gen. Parmigianino Francesco Mazzola',
#         'Permensiano', 'Parmiggiano', 'Parmegian', 'Permegiano',
#         'Parmeggianini', 'dit le Parmesan François Mazzuoli', 'Parmesanio',
#         'Francesco Mazzuoli detto il Parmigianino', 'Permigianino',
#         'Parmessano', 'Parmegino', 'Permens', 'Parmegine',
#         'Francesco gen. Parmigianino Mazzuoli',
#         'Francesco Maria Mazzola Parmigianino', 'Permesano',
#         'Francesco Parmesiane',
#         'eigentlich Francesco Maria Mazzuola Parmigianino',
#         'detto il Parmigianino Francesco Mazzuoli',
#         'Francesco Mazzuoli, detto, Parm. Parmeggiano', 'le Parmezan',
#         'francesco mazzuola', 'Pamegiano', 'F. Mazzola',
#         'Francisco Parmitiaen', 'Francesco Mazzuolo detto il Parmigianino',
#         'parmasano', 'François Mazuoli', 'T. Parmegiano', 'Pomoganino',
#         'Francisco Parmisano', 'Parmegians', 'Parmeg.no', 'el parmesano',
#         'Varmesano', 'Palmigianino', 'Franz Mazoli',
#         'F.co Mazzola detto Parmigianino', 'f. mazzuola', 'Parmesiano',
#         'francesco mazzuola il parmigiano',
#         'dit Parmesan Francesco Mazzuoli', 'Francisco Parmens',
#         'Parmijiano', 'Parmegg.no', 'Parmezian',
#         'detto Parmigianino Francesco Mazzuoli', 'Francisco Parmesano',
#         'F. Parmegiano', 'dit Parmesan F. Masoli',
#         'dit Le Parmesan Parmesino', 'francesco Parmigianino',
#         'Fran.o Mazzoli Parmiggiano', 'Parmiggianino',
#         'commonly called the Parmegianino Francis Mazzola',
#         'genannt Parmeggiano, oder Parmesan Franz Mazzoli', 'Mazzuolo',
#         'Francesco Parmigianino d. i. Mazzuola', 'Parmaceino', 'Parmesani',
#         'dit le Parmesan François Mazzuola',
#         'Francesco Mazzuola gen. Jl. Parmegianino', 'Parmisanino',
#         'Fran. Mazziola Parmegiano', 'dit le Parmesan Francesco Mazzuoli',
#         'Massola', 'Francesco Mazzuola, il Parmiggiano', 'Parmigiuno',
#         'Mazoli', 'Frantz Mazzoli', 'Parmeggianino scolaro del Correggio',
#         'Pernigianimi', 'Genannt il Parmigianino Francesco Maria Mazzola',
#         'F. Parmigianino', 'called Parmegiano Francisco Mazzuoli',
#         'Francesco Mazzuoli dit Parmegiano', 'F. Parmesan', 'Permesianini',
#         'Francesco Mazzuola gen. Parmigianino', 'Parmezanino',
#         'Francesco Parmigiano', 'Parmigia[ni]no',
#         'dit le Parmesan François Mazzoli',
#         'Genannt Il Parmegianino Mazzola',
#         'dit le Parmesan François Mazzola', 'François Parmesan',
#         'Parmisani', 'Masoli', 'Parmensis', 'Franchesco Parmiggiano',
#         'Francisco Parmegiano', 'Mazuoli dit le Parmezan', 'Parmesciano',
#         'Permence', 'Parmigiannino',
#         'francesco mazzuela gen. il parmegianino', 'Frances Parmigianino',
#         'Francesco Parmegiano', 'Pamesiano', 'Parme', 'Francois Parmesan',
#         'Girolamo-Francesco-Maria, gen. Parmigianino Mazzola', 'Parma',
#         'François Mazoli', 'Francesco Mazzola detto il Parmigianino',
#         'Francesco Parmesano', 'Parmesanin', 'Masola',
#         'Girolamo Francesco Maria (Il Parmigianino) Mazzola'], dtype=object),
#  array(['Sima Chin', 'Ssu-ma Chien', 'Zichang'], dtype=object),
#  array(['Arnold Daniel Palmer'], dtype=object),
#  array(['Seal of the Prophets', 'The Prophet', 'The Messenger', 'Mohammad',
#         'Muhammed', "Abu'l-Qasim", 'Mohammed',
#         "Abu al-Qasim ibn 'Abd Allah ibn 'Abd al-Muttalib ibn Hashim",
#         'Muhammad ibn Abdullah', 'Ahmad', 'Servant of Allah',
#         'Prophet Muhammad', 'Mahomet'], dtype=object),
#  array(['Abdul Kalam', 'Avul Pakir Jainulabdeen Abdul Kalam', 'Kalam',
#         'A.P.J Abdul Kalam', 'A P J Abdul Kalam'], dtype=object),
#  array(['Abdul Rashid Salim Salman Khan', 'Salman Khan'], dtype=object),
#  array(['Martinos Luter', 'Marczin Luther', 'Martti Luther', 'Martin Lutr',
#         'Marcin Luter', 'Mātīn Lūtœ', 'Martí Luther', 'Mārtiņš Luters',
#         'Martín Lutero', 'Márton Luther', 'Marṭin Luter', 'D. M. L. A.',
#         'Luttar Cāstiriyār', 'Martinus Luther', 'Maarten Luther', 'Luther',
#         'Lutʻŏ', 'Marti Luther', 'Martin Lutero', 'Marton Luther'],
#        dtype=object),
#  array(['Harivansh Rai Shrivastav', 'Bachchan'], dtype=object),
#  array(['Richard Milhous Nixon', 'Nixon', 'President Nixon', 'Dick Nixon',
#         'Tricky Dick', 'R. Nixon', 'R. M. Nixon', 'Richard M. Nixon'],
#        dtype=object),
#  None,
#  array(['Schumi'], dtype=object),
#  None,
#  array(['Li Yu', 'Li Chu', 'Li Yu(8)', 'Dai Zong', 'Li(2) Shu'],
#        dtype=object),
#  array(['Li Song(6)', 'Shun Zong', 'Emperor Zhide', "Dasheng Da'an Xiao",
#         'Li Song'], dtype=object),
#  array(['Zhu Qizhen', 'Tianshun',
#         'Fatianlidaorenmingchengjingzhaowenxianwuzhideguangxiaoruihuangdi',
#         'Tianshun Emperor', 'Rui Di', 'Zhengtong', 'Ying Zong'],
#        dtype=object),
#  array(['Zhu Youcheng',
#         'Datianmingdaochunchengzhongzhengshengwenshenwuzhirendadejinghuangdi',
#         'Hongzhi', 'Zhu Youtang', 'Xiao Zong', 'Jing Di'], dtype=object),
#  array(['Zhengde',
#         'Chengtiandadaoyingsuruizhezhaodexiangonghongwensixiaoyihuangdi',
#         'Wu Zong', 'Zhu Houzhao', 'Daqingfawang', 'Yi Di', 'Shou'],
#        dtype=object),
#  None,
#  array(['Taichang', 'Guang Zong', 'Zhu Changluo',
#         'Chongtianqidaoyingruigongchunxianwenjingwuyuanrenyixiaozhenhuangdi',
#         'Zhen Di'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Edith Margaret Hannam', 'Edith Boucher'], dtype=object),
#  None,
#  array(['Alain Marie Pascal Prost'], dtype=object),
#  array(['Thomas William Cleverley'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Steve Beleck', "Steve Leo Beleck A'Beka"], dtype=object),
#  None,
#  None,
#  None,
#  array(['Al-Batani', 'Albategnius', 'Al-Battani', 'Muhammad al-Battani'],
#        dtype=object),
#  array(['Stephen Gerald Breyer'], dtype=object),
#  array(['Fulgencio Batista y Zaldivar'], dtype=object),
#  array(['Susan Elizabeth Black', 'Dr Sue Black'], dtype=object),
#  array(['Kay Rala Xanana Gusmão', 'José Alexandre Gusmão'], dtype=object),
#  array(['Annie J. Easley'], dtype=object),
#  array(['Stanley Anthony Coveleski', 'Stanley Coveleski'], dtype=object),
#  None,
#  array(['Anne Marbury', 'Ann Marbury'], dtype=object),
#  None,
#  array(['Shawn Hailey'], dtype=object),
#  array(['David Alexander Paterson'], dtype=object),
#  None,
#  array(['President Jefferson', 'T. Jefferson'], dtype=object),
#  array(['J. Tyler', 'President Tyler', 'John Tyler, Jr.', 'John Tyler Jr.',
#         'John Tyler Jr', 'John Tyler, Jr'], dtype=object),
#  array(['James Knox Polk', 'James Polk', 'J. K. Polk', 'J. Polk',
#         'President Polk'], dtype=object),
#  None,
#  array(['Belarmino Maria Austregésilo Augusto de Athayde',
#         'Austregesilo de Athayde',
#         'Belarmino Maria Austregesilo Augusto de Athayde'], dtype=object),
#  array(['Guido Nolitta'], dtype=object),
#  array(['James Buchanan, Jr.', 'J. Buchanan, Jr.', 'J. Buchanan',
#         'President Buchanan'], dtype=object),
#  array(['Elena Alexandra Apostoleanu'], dtype=object),
#  None,
#  array(['Kalman Kalocsay'], dtype=object),
#  array(['Damián Campeny', 'Damia Campeny',
#         'Damián Buenaventura Campeny y Estrada',
#         'Damián Buenaventura Campeny Estrany',
#         'Damián Buenaventura Campeny y Estrany',
#         'Damián Campeny y Estrany', 'Damià Campeny',
#         'Damià Campeny Estrany', 'Damia Campeny i Estrany',
#         'Damian Campeny', 'Damian Buenaventura Campeny y Estrada',
#         'Damian Buenaventura Campeny Estrany',
#         'Damian Buenaventura Campeny y Estrany',
#         'Damian Campeny y Estrany', 'Damia Campeny Estrany'], dtype=object),
#  array(['Baghy Gyula', 'Gyula Baghy', 'Jobo', 'Paĉjo'], dtype=object),
#  array(['Mary Beth Patterson'], dtype=object),
#  array(['Bertil Wennergren'], dtype=object),
#  None,
#  None,
#  array(['Inoue Hisashi'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  array(['Leopold I', 'King Leopold I of Belgium',
#         'Leopold, King of the Belgians', 'Leopold of Saxe-Coburg-Gotha',
#         'Leopold of Saxe-Coburg-Saalfeld'], dtype=object),
#  array(['Polydore Louis Lippens'], dtype=object),
#  array(['Teodoro Schwartz', 'Teo Melas'], dtype=object),
#  array(['Remy Vercoutre'], dtype=object),
#  None,
#  None,
#  array(['Georgy Vladimirovich Zaborsky', 'Georgy Zaborsky'], dtype=object),
#  array(['Josef Langbard', 'Iosif Grigor’evich Langbard',
#         "Iosif Grigor'yevich Langbard"], dtype=object),
#  array(['Jean-Pierre Roger Guillaume Papin'], dtype=object),
#  array(['Merikukka Forsius-Harkimo'], dtype=object),
#  None,
#  array(['Luchino Visconti, conte di Modorone',
#         'Don Luchino Visconti di Modrone, Conte di Lonate Pozzolo'],
#        dtype=object),
#  array(['Alberto Bayo y Giroud', 'Alberto Bayo Giroud'], dtype=object),
#  array(['Ursula Hilda Mary Martin', 'Ursula Hilda Mary Webb'], dtype=object),
#  array(['Antonio "Tony" Ramiro Romo'], dtype=object),
#  None,
#  array(['Richard Melville Hall', 'Voodoo Child', 'Barracuda', 'Brainstorm',
#         'Schaumgummi', 'Pippy Baliunas', 'UHF', 'Elizabeth McBride'],
#        dtype=object),
#  array(['Spencer Baird', 'Baird', 'Spencer F. Baird'], dtype=object),
#  None,
#  None,
#  array(['A. Orebaugh', 'A Orebaugh', 'Orebaugh', 'Orebaugh A',
#         'Orebaugh A.'], dtype=object),
#  array(['Wanda Janina Orlikowski', 'Wanda J. Orlikowski'], dtype=object),
#  array(['Susan S Owicki', 'Susan Speer Owicki'], dtype=object),
#  None,
#  None,
#  array(['Diane L. Souvaine'], dtype=object),
#  None,
#  array(['Frederick William Herschel', 'Sir William Herschel'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Pelayo', 'Don Pelayo', 'Pelayo, King of Asturias',
#         'Pelagius of Asturias'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Volodymyr Sviatoslavych', 'Volodymyr the Great',
#         'Vladimir Svyatoslavich', 'Valdamar', 'Volodimer',
#         'Volodymyr of Kyiv'], dtype=object),
#  array(['Leon Delacroix'], dtype=object),
#  None,
#  array(['Tsang Yam-kuen', 'Zeng Yinquan'], dtype=object),
#  array(['José Pablo Torcuato Batlle y Ordóñez'], dtype=object),
#  array(['R.E.Fr.'], dtype=object),
#  array(['V.Brig.', 'Vincenzio Briganti'], dtype=object),
#  None,
#  array(['Jack'], dtype=object),
#  None,
#  None,
#  array(['Dwayne Carter', 'Dwayne Michael Carter Jr.', 'Tunechi',
#         'Weezy F. Baby', 'Dwayne Carter Jr.', 'The President',
#         'Best Rapper Alive'], dtype=object),
#  None,
#  array(['Jarkko Maeaettae'], dtype=object),
#  None,
#  array(['Daniel Alberto Passarella'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Emile Durkheim'], dtype=object),
#  array(['Charles-Louis de Secondat, baron de La Brède et de Montesquieu',
#         'Charles-Louis de Secondat', 'Baron de Montesquieu',
#         'Charles Louis de Secondat de Montesquieu', 'De Montesquieu'],
#        dtype=object),
#  None,
#  None,
#  None,
#  array(['Schäuble, Wolfgang', 'Wolfgang Schaeuble', 'Wolfgang Schauble',
#         'Schauble, Wolfgang', 'Schaeuble, Wolfgang'], dtype=object),
#  array(['Brenno Benedetti Farrugia'], dtype=object),
#  None,
#  array(['Charles Kao', 'Charles Kuen Kao', 'Kuen Kao', 'Kao Kuen',
#         'Gao Kun'], dtype=object),
#  array(['Lee Jun-fan', 'Li Xiaolong'], dtype=object),
#  None,
#  array(['Clive Robin Sarstedt', 'Wes Sands', 'Clive Sands'], dtype=object),
#  array(['Jiabao Wen'], dtype=object),
#  array(['Liu Dehua', 'Lau Tak Wah', 'Andy Lau Tak-wah'], dtype=object),
#  None,
#  array(['Poe', 'Edgar Poe', 'E. A. Poe'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Pontius Pilate', 'Pilatus', 'Pilate'], dtype=object),
#  array(['Xavi Hernandez Creus'], dtype=object),
#  array(['Kathleen McNulty Mauchly Antonelli', 'Kay Antonelli'],
#        dtype=object),
#  None,
#  None,
#  array(['Psappho', 'Sapphus', 'Sapho'], dtype=object),
#  array(['J.Clayton'], dtype=object),
#  array(['Boissonneau'], dtype=object),
#  array(['Attila A. Toth'], dtype=object),
#  array(['E. Bick'], dtype=object),
#  array(['Emile Boirac'], dtype=object),
#  array(['Osmo Tapani Buller'], dtype=object),
#  array(['Montagu Christie Butler', 'M. C. Butler'], dtype=object),
#  array(['Geza Imre'], dtype=object),
#  None,
#  None,
#  array(['Rebecca Renee Black'], dtype=object),
#  array(["Anatoly Vasil'yevich Lunacharsky"], dtype=object),
#  array(['Samuel Stewart Witwer'], dtype=object),
#  None,
#  array(['Heather Laurie Holden'], dtype=object),
#  array(['theos.com', 'deraadt'], dtype=object),
#  array(['Ryry', 'Ryan Whitney Newman'], dtype=object),
#  array(['Edwin McMillan', 'McMillan, E. M.', 'McMillan, E.',
#         'E. M. McMillan'], dtype=object),
#  array(['Güiza'], dtype=object),
#  None,
#  None,
#  array(['Pal Bajai'], dtype=object),
#  array(['Arthur Ernest Percival'], dtype=object),
#  array(['Chester Charles Bennington'], dtype=object),
#  None,
#  None,
#  array(['William Anders', 'William Alison Anders'], dtype=object),
#  None,
#  array(['Philip II of Palatine Burgundy', 'Philip III of Artois',
#         'Philip III of Boulogne and Auvergne', 'Philip of Rouvres'],
#        dtype=object),
#  None,
#  array(['Vicente Guaita Panadero'], dtype=object),
#  array(['Éver Maximiliano David Banega'], dtype=object),
#  None,
#  array(['Oscar dos Santos Emboaba Junior', 'nior'], dtype=object),
#  array(['Steven Paul Jobs', 'Steven Jobs'], dtype=object),
#  array(['Juan Carlos',
#         'Juan Carlos Alfonso Víctor María de Borbón y Borbón-Dos Sicilias',
#         'Juan Carlos Alfonso Victor Maria de Borbon y Borbon-Dos Sicilias',
#         'His Majesty Juan Carlos I, King of Spain',
#         'Juan Carlos I of Spain', 'Juan Carlos of Spain',
#         'King Juan Carlos',
#         'Juan Carlos Alfonso Victor Maria de Borbón y de Borbón, Rey de España'],
#        dtype=object),
#  array(['Henri Louis Grin'], dtype=object),
#  array(['George Airy', 'Sir George Biddell Airy'], dtype=object),
#  array(['Sergey Petrovich Kapitsa', 'Serguei Kapitza'], dtype=object),
#  None,
#  None,
#  array(['Sebastian Carmine Ingrosso', 'Ingrosso'], dtype=object),
#  array(['Alexandre Gustave Eiffel'], dtype=object),
#  None,
#  array(['Elisée Reclus', 'Jacques Elisée', 'Elisee Reclus',
#         'Jacques Elisee', 'Élysée Reclus', 'Elisha Reclus'], dtype=object),
#  None,
#  None,
#  array(['Dorothy Donaldson Fleming'], dtype=object),
#  array(['Tracy Ellen Caldwell'], dtype=object),
#  None,
#  None,
#  None,
#  array(['James Warren "Jim" DeMint', 'James Warren DeMint'], dtype=object),
#  array(['Olympia J. Snowe', 'Olympia Bouchles'], dtype=object),
#  array(['Chu Teh'], dtype=object),
#  None,
#  None,
#  array(['Anno Hideaki'], dtype=object),
#  array(['Stanley Melbourne Bruce',
#         'Stanley Melbourne Bruce, 1st Viscount Bruce of Melbourne',
#         'The Right Honourable The Viscount Bruce of Melbourne',
#         'Viscount Bruce of Melbourne'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Ricky Dene Gervais'], dtype=object),
#  array(['Jimmy E. Carter', 'James Earl Carter Jr.',
#         'James Earl "Jimmy" Carter Jr', 'James E. Carter',
#         'Jimmy Earl Carter', 'James Carter', 'James Earl Carter',
#         '39th President of the United States', 'James Earl "Jimmy" Carter',
#         'President Carter', 'President Jimmy Carter',
#         'James E. Carter Jr.', 'James Earle Carter',
#         'James "Jimmy" Carter', 'James Earl (Jimmy) Carter',
#         'James Earl Carter, Jr.', 'James Earl "Jimmy" Carter, Jr.'],
#        dtype=object),
#  array(['Kimo', 'Kim Henriksen'], dtype=object),
#  array(['Sir Ebenezer Howard', 'E. Howard'], dtype=object),
#  None,
#  None,
#  array(['Lou Cristillo', 'Louis Francis Cristillo'], dtype=object),
#  None,
#  array(['Andrew Panko'], dtype=object),
#  array(['Lord Digby Jones', 'Digby', 'Baron Jones of Birmingham',
#         'Digby Jones, Baron Jones of Birmingham', 'Digby Marritt Jones'],
#        dtype=object),
#  None,
#  array(['Raoul Banfi', 'Raul Banfi'], dtype=object),
#  None,
#  None,
#  array(['Andrei Kashechkin', 'Andrej Kashechkin', 'Andriy Kaschechkin',
#         'Andrey Kaschechkin', 'Andrey Kachechkin'], dtype=object),
#  array(['Anthon Gerhard Alexander van Rappard',
#         'Anthon Gerhard Alexander Ridder van Rappard',
#         'Anthon, Ridder van Rappard', 'Anton Gerhard Alexander Rappard',
#         'Anthon Van Rappard', 'Anton Gerhard Alexander van Rappard',
#         'Anthon Gerhard Alexander Rappard',
#         'Anthon Gerhard Alexander, Ridder van Rappard',
#         'Anton Gerhard Alexander Ritter van Rappard',
#         'Anton Gerhard Alexander Van Rappard', 'Anthon Ridder van Rappard',
#         'Alexander Rappard', 'Anthon Gerard Alexander ridder van Rappard',
#         'Anthon Gerhard Alexander van Rappard (ridder)',
#         'Anthon Gerard Alexander Ridder van Rappard'], dtype=object),
#  array(['Anthony Ray Swarzak'], dtype=object),
#  array(['Levi Jared Burton'], dtype=object),
#  array(['Aloys Thomas Raimund Graf Harrach',
#         'Aloys Thomas Raimund von Harrach', 'Aloys Thomas',
#         'Aloys Thomas Raimund Count Harrach',
#         'Viceroy of Naples1669-1742 Aloys Thomas Raimund Graf von Harrach',
#         'Aloys, Graf von Harrach', 'Luise Raimondo Harach',
#         'Aloys Thomas Raimund Graf von, Viceroy of Naples Harrach',
#         'Aloys Harrach Graf von', 'Aloys, Graf Von Harrach',
#         'Luise Raimondo, conte di Harach', 'Louis, Graf von Harrach'],
#        dtype=object),
#  None,
#  array(['Helena Antonia Galecka'], dtype=object),
#  None,
#  None,
#  array(['Richard Henry Meinertzhagen CBE DSO',
#         'Richard Henry Meinertzhagen', 'Colonel Richard Meinertzhagen',
#         'Colonel Richard Henry Meinertzhagen',
#         'Colonel Richard Henry Meinertzhagen CBE',
#         'Richard Henry Meinertzhagen CBE'], dtype=object),
#  array(['Aleksey Aleksandrovich Maksimov'], dtype=object),
#  None,
#  None,
#  array(['Kubanychbek Zhumaliev', 'Kubanychbek Jumaliev',
#         'Kubanychbek Myrzabekovich Jumaliyev'], dtype=object),
#  None,
#  None,
#  array(['Zhumabek Ibraimov', 'Jumabek Ibraimovich Ibraimov'], dtype=object),
#  None,
#  array(['George Orson Welles'], dtype=object),
#  array(['Anker Sorensen', 'Anker'], dtype=object),
#  None,
#  None,
#  array(['Louis-Maxime Raybaud', 'Maxime Raybaud'], dtype=object),
#  array(['Charles F. Bolden', 'Charlie Bolden', 'Charles Frank Bolden',
#         'Charles F. Bolden Jr.', 'Charles F. Bolden Jr',
#         'Charles Frank Bolden, Jr'], dtype=object),
#  array(['John Marwood Cleese'], dtype=object),
#  array(['Harry Valerien'], dtype=object),
#  array(['Duke of Teck'], dtype=object),
#  array(['Terrence Vance Gilliam'], dtype=object),
#  array(['Muhammad al-Taqi'], dtype=object),
#  array(['Zdenek Fiala'], dtype=object),
#  array(['Kevin Spacey Fowler'], dtype=object),
#  array(['Francesco Battiato', 'Süphan Barzani'], dtype=object),
#  None,
#  array(['Larry Christopher Allen Senior'], dtype=object),
#  array(['Todd Christopher Young', 'Senator Todd Young', 'Senator Young',
#         'Sen. Todd Young', 'Sen. Young'], dtype=object),
#  None,
#  array(['Konstantin Alexander Karl Wilhelm von Benckendorff',
#         'Count Alexander Khristoforovich Benckendorff'], dtype=object),
#  None,
#  array(['Francis Russell'], dtype=object),
#  array(['Pieter Helbert Damste', 'P.H. Damsté'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['Elisabeth Martens', 'Louise Cathrine Elisabeth Bjørnsen'],
#        dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['Walter Klemm'], dtype=object),
#  None,
#  array(['Mikko Henrik Julius Paananen', 'Migé Amour', 'Migé',
#         'Mikko Henrik Paananen', 'Bad Bad Mizee', 'Michael Eros',
#         'Mige Amour', 'Mige'], dtype=object),
#  array(['Hermann Karl Hesse'], dtype=object),
#  None,
#  None,
#  array(['Frederic Michael Lynn', 'Frederic M. Lynn'], dtype=object),
#  array(['Barbara Myasnikov', 'Varvara Sergeyevna Myasnikova'], dtype=object),
#  array(['Carlos Roberto PenaVega', 'Carlos Roberto Pena, Jr.',
#         'Carlos Pena, Jr.', 'Carlos Pena, Jr', 'Carlos Pena Jr'],
#        dtype=object),
#  None,
#  None,
#  array(['Sophie Moressee-Pichot'], dtype=object),
#  None,
#  array(['Mikhail Mikhaylovich Varnakov'], dtype=object),
#  array(['Zivile Raudoniene'], dtype=object),
#  array(['Carol W. Greider', 'Carolyn Widney Greider',
#         'Carolyn Widney "Carol" Greider', 'Carol W Greider',
#         'C. W. Greider', 'C W Greider', 'C. Greider', 'C Greider',
#         'Greider', 'Greider C', 'Greider C.', 'Greider C. W.',
#         'Greider CW', 'CW Greider'], dtype=object),
#  None,
#  None,
#  array(['David C. Giuntoli'], dtype=object),
#  None,
#  array(['Raymond Chan Chi-chuen', 'Chan Chi-chuen', 'Ray Chan',
#         'Chen Zhiquan'], dtype=object),
#  None,
#  array(['Danny de Vito'], dtype=object),
#  array(['Leon White', 'Big Van Vader'], dtype=object),
#  array(['Taylor Alison Swift', 'Nils Sjöberg'], dtype=object),
#  array(['Melville Louis Kossuth Dewey'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  array(['Frederic Hantz'], dtype=object),
#  None,
#  None,
#  array(['Ebert, Patrick'], dtype=object),
#  array(['Jin Yi-han', 'Jin Yi Han', 'Jin I-han'], dtype=object),
#  None,
#  None,
#  array(['Julien Sable'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Scott Edward Adkins'], dtype=object),
#  None,
#  array(['Nicholas Christian Hopkins'], dtype=object),
#  array(['Alvin E. Roth', 'Alvin Roth', 'Alvin Elliot Roth'], dtype=object),
#  None,
#  None,
#  array(['Yizhai'], dtype=object),
#  None,
#  array(['Sir John Scott Burdon-Sanderson, 1st Baronet',
#         'Sir John Burdon-Sanderson, 1st Baronet',
#         'John Scott Burdon-Sanderson'], dtype=object),
#  array(['Evgeny Vakker'], dtype=object),
#  array(['Pangeran Diponegoro', 'Prince Diponegoro'], dtype=object),
#  array(['János György Kemény', 'John G. Kemeny'], dtype=object),
#  None,
#  array(['Tumen', 'Bumın Kagan', 'Illig Qaghan'], dtype=object),
#  array(['Charles William Chadwick Oman',
#         'Sir Charles William Chadwick Oman', 'C. W. C. O.'], dtype=object),
#  array(['Gaetano Apolline Baldassarre Vestris',
#         'Gaetano Apoline Balthazar Vestris', 'Gaetan Vestris'],
#        dtype=object),
#  array(['Rajasanagara'], dtype=object),
#  array(['Matthew Lyn Lillard', 'mathew lillard'], dtype=object),
#  None,
#  array(['John Horace Round', 'J. H. Round'], dtype=object),
#  None,
#  None,
# ...
#         'R. Koch', 'R Koch', 'Koch', 'Koch R', 'Koch R.'], dtype=object),
#  array(['Nestor Camacho'], dtype=object),
#  array(['Albino Luciani', 'John Paul', 'Pope John Paul I',
#         'papa Giovanni Paolo I', 'Pope Giovanni Paolo I',
#         'Iohannes Paulus PP. I', 'Johannes Paulus'], dtype=object),
#  array(['John Talbot'], dtype=object),
#  None,
#  array(['Donato di Niccolò di Betto Bardi',
#         'Donato di Niccolo di Betto Bardi', 'Donatello Donato'],
#        dtype=object),
#  None,
#  array(['Milena Markovna Kunis'], dtype=object),
#  array(['Manuel de Escandon'], dtype=object),
#  array(['King of Korea Sedzhon', 'the Great Seijong',
#         'King of Korea Yi Sejong', 'King of Korea Yi To', 'Sejong',
#         'King of Korea Sejong', 'Se Jong', 'Li Tao', 'Shizong',
#         'Yuanzheng', 'Yingwenruiwurenshengmingxiaodaiwang', 'Yingling',
#         'Zhuangxian'], dtype=object),
#  array(['Carl Johannes Nielsen'], dtype=object),
#  array(['Helen Adams Keller'], dtype=object),
#  array(['Eithne Ní Bhraonáin', 'Enya Brennan', 'Eithne Ni Bhraonain',
#         'Eithne Pádraigín Ní Bhraonáin', 'Eithne Padraigin Ni Bhraonain'],
#        dtype=object),
#  None,
#  None,
#  None,
#  array(['Anthony Oliver Scott'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Tsvetan Dinew'], dtype=object),
#  array(['Lubomir Kolnik'], dtype=object),
#  None,
#  None,
#  array(['Steven Adam Markowitz', 'Andrew Alen'], dtype=object),
#  array(['Recep Tayyip Erdogan', 'Tayyip Erdoğan', 'Tayyip Erdogan',
#         'Erdoğan', 'Erdogan'], dtype=object),
#  None,
#  None,
#  array(['Tomita Yoshiro', 'Tomita Yoshirou'], dtype=object),
#  None,
#  array(['Clement Leroy Otter', 'Clement Otter',
#         'Clement Leroy "Butch" Otter', 'Governor Butch Otter'],
#        dtype=object),
#  None,
#  array(['Matthew William Sorum'], dtype=object),
#  array(['John Lewis Burckhardt', 'Jean Louis Burckhardt',
#         'Jean-Louis Burckhardt'], dtype=object),
#  array(['Jonathan Serge Folly Ayité'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Michel de Nostredame', 'Michel Nostradamus'], dtype=object),
#  None,
#  array(['Lucy Ursula Griffiths'], dtype=object),
#  None,
#  array(['Bulgaro'], dtype=object),
#  array(['Chandra Danette Wilson'], dtype=object),
#  None,
#  array(['Muhammad Jamalul Alam II of Brunei',
#         'Pengiran Muda Bongsu Muhammad Jamalul Alam'], dtype=object),
#  None,
#  array(['Raul Valerio'], dtype=object),
#  None,
#  array(['Tammy Suzanne Green Baldwin'], dtype=object),
#  array(['St John the Baptist', 'Ioannes Baptista',
#         'Saint John the Baptist', 'St. John the Baptist'], dtype=object),
#  None,
#  array(['Dilma Vana Rousseff'], dtype=object),
#  None,
#  array(['Jenner'], dtype=object),
#  array(['Doris May Tayler', 'Jane Somers'], dtype=object),
#  array(['Evita', 'Eva Peron', 'Maria Eva Duarte de Peron',
#         'Maria Eva Duarte Peron', 'María Eva Duarte de Perón',
#         'María Eva Duarte Perón', 'Evita Perón', 'Eva'], dtype=object),
#  array(['Daniel Foe'], dtype=object),
#  array(['Martin Skorseze'], dtype=object),
#  array(['Air Jordan', 'Michael Jeffrey Jordan', 'His Airness',
#         'Jordan, Michael'], dtype=object),
#  array(['Jan Sergiusz Gajek'], dtype=object),
#  None,
#  array(['Mies van der Rohe', 'Mies', 'Maria Ludwig Michael Mies',
#         'Liudvig Mis van der Rohe', 'Ludwig Mies',
#         'Ludwig Mies Van der Rohe', 'Ludvig Mis van der Roė',
#         'Maria Ludwig Michael Mies van der Rohe',
#         'Ludwig Mies Van Der Rohe', 'Ludwig MiesvanderRohe'], dtype=object),
#  array(['Adrianus Schenk'], dtype=object),
#  None,
#  array(['Susan Jane Helms'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Kathryn Patricia Kay Hire', 'Kathryn Patricia Hire', 'Kay Hire'],
#        dtype=object),
#  array(['Philip Mahre'], dtype=object),
#  None,
#  None,
#  array(['Romanus III Argyrus, Emperor of Constantinople', 'Romanus III'],
#        dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['Alexander Antonovich Solodukha'], dtype=object),
#  array(['Michael V Calaphates, Emperor of Constantinople', 'Michael V'],
#        dtype=object),
#  array(['Kenneth Miller'], dtype=object),
#  None,
#  array(['Rosa "Lee" Louise McCauley Parks', 'Rosa Louise McCauleyParks'],
#        dtype=object),
#  array(['Democritos', 'Democritus of Abdera'], dtype=object),
#  None,
#  None,
#  array(['Henri-Louis Bergson', 'H. Bergson', 'Henry Bergson',
#         'Henri Louis Bergson', 'Berxon'], dtype=object),
#  array(['Bruddah Iz', 'IZ'], dtype=object),
#  None,
#  None,
#  array(['Maria Wisława Anna Szymborska', 'Szymborska'], dtype=object),
#  None,
#  array(['Leif Eiricson', 'Leif Ericson', 'Leif Eriksson',
#         'Leifur Eríksson', 'Leifur Eiriksson', 'Leifur Eriksson',
#         'Leif the Lucky', 'Lonely Hermit'], dtype=object),
#  array(['Dustin Lee Hoffman'], dtype=object),
#  array(['Pavlov Ivan'], dtype=object),
#  array(['Manoel Cândido Pinto de Oliveira'], dtype=object),
#  None,
#  array(['León Quaglia', 'Léon Giotti Quaglia', 'Léonhard Giotti Quaglia',
#         'Leonhard Quaglia', 'Leon Quaglia', 'Leon Giotti Quaglia',
#         'Leonhard Giotti Quaglia'], dtype=object),
#  None,
#  array(['Antonie Van Leeuwenhoek', 'Antoni  van  Leeuwenhoek'],
#        dtype=object),
#  array(['Tatanka Iyotanka', 'Sitting Buffalo Bull', 'Chief Sitting Bull'],
#        dtype=object),
#  None,
#  None,
#  None,
#  array(['saint ambrose', 'St. Ambrosius', 'St. Ambrose',
#         'Saint, Bishop of Milan Ambrogio', 'Ambrosius von Mailand',
#         'Saint, Bishop of Milan Aurelius Ambrosius', 'Saint Ambrose',
#         'Saint, Bishop of Milan Ambrose', 'Saint, Bp. of Milan Ambrosius',
#         'Saint, Bishop of Milan Ambroise',
#         'Saint, Bishop of Milan Amvrosīĭ', 'Ambrosius Mediolanensis',
#         'Saint, Bishop of Milan Aurelio Ambrogio',
#         'Saint Ambrose Bishop of Milan', 'Ambrosius', 'Ambrose of Milan',
#         'St Ambrose'], dtype=object),
#  array(['Vlad the Impaler', 'Vlad III the Impaler', 'Vlad III',
#         'Vlad Dracula', 'Vlad III Dracula', 'Vladimir Tepes'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  array(['Irina Vladimirovna Kiseleva'], dtype=object),
#  None,
#  None,
#  array(['Gusztav Olah'], dtype=object),
#  None,
#  None,
#  array(['Emilio Norberto Otto Max Gastel', 'Emilio Norberto Gastell'],
#        dtype=object),
#  array(['Pope Leo XIII', 'Vincenzo Gioacchino Raffaele Luigi Pecci',
#         'Leo PP. XIII', 'Pope Léon XIII', 'Pope Lev XIII',
#         'papa Leone XIII', 'Pope Leone XIII', 'Gioacchino Vincenzo Pecci',
#         'Pope Leon XIII'], dtype=object),
#  array(['Angus McKinnon Young'], dtype=object),
#  array(['Jose Toure'], dtype=object),
#  array(['Tamara Lynn Sytch', 'Tammy Spirit', 'Tammy Lynn Fytch',
#         'Tamara Murphy', 'Sunny', 'Tamara "Tammy" Lynn Sytch'],
#        dtype=object),
#  None,
#  array(['Edno'], dtype=object),
#  None,
#  array(['Schiele', 'schiele egon', 'e. schiele'], dtype=object),
#  array(['Ludwig II.'], dtype=object),
#  array(['Zeynel Dogan'], dtype=object),
#  None,
#  array(['Werner Herzog Stipetić', 'Werner Stipetić'], dtype=object),
#  None,
#  None,
#  array(['Mai Yamada', 'Hazuki Riona'], dtype=object),
#  None,
#  array(['Saint Ignatius of Loyola', 'Saint Ignatius', 'Ignatius of nepeya',
#         'of Loyola, Saint Ignatius', 'Ignatius Loyola'], dtype=object),
#  array(['Rudolf Ludwig Mössbauer'], dtype=object),
#  array(['Zakry Abdul Latif'], dtype=object),
#  None,
#  array(['Ulrich Hoeneß'], dtype=object),
#  None,
#  array(['John Theodore Rossi'], dtype=object),
#  array(['Tarcisio Pietro Evasio Bertone'], dtype=object),
#  None,
#  None,
#  array(['Philippe Omnes'], dtype=object),
#  array(['Ray Anthony Lewis'], dtype=object),
#  None,
#  None,
#  array(['Randal Keith Orton', 'Viper', 'The Viper', 'RKO'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['His-Horse-Is-Crazy', 'Tȟašúŋke Witkó'], dtype=object),
#  array(['Eduardo Hughes Galeano', 'Eduardo Germán María Hughes Galeano',
#         'Eduardo German Maria Hughes Galeano'], dtype=object),
#  array(['François Guichardin', 'Guicciardini'], dtype=object),
#  None,
#  array(['Wyatt Berry Stapp Earp'], dtype=object),
#  array(['Peter Canisius, S.J.'], dtype=object),
#  array(['Moise Brou Apanga'], dtype=object),
#  None,
#  array(['Otfried Preussler', 'Hannes Hauser'], dtype=object),
#  None,
#  array(['Malcolm Mitchell Young'], dtype=object),
#  None,
#  array(['Chavo Guerrero Jr', 'Chavo Guerrero, Jr.', 'Salvador Guerrero IV'],
#        dtype=object),
#  None,
#  array(['Itzik Fefer'], dtype=object),
#  None,
#  None,
#  array(['Giovanni Battista Cardinal Re'], dtype=object),
#  None,
#  array(['Dolk Lundgren', 'Dolk'], dtype=object),
#  array(['Josef Maria Olbrich'], dtype=object),
#  None,
#  None,
#  array(['Lemon Henry Jefferson', 'Deacon L. J. Bates',
#         'Lemon Henry "Blind Lemon" Jefferson'], dtype=object),
#  array(['Franz, Ritter von Stuck', 'Franz Ritter von Stuck',
#         'Franz Stuck Ritter von', 'Frans von Stuck', 'Franz Von Stuck',
#         'Franz von Stuck', 'f. stuck', 'stuck franz', 'f. v. stuck',
#         'Stuck', 'f. von stuck', 'stuck franz von',
#         'franz von, prof. stuck', 'prof. f. stuck', 'franz von, M. stuck',
#         'franz stuck', 'professor franz v. stuck', 'fr. v. stuck',
#         'fr. von stuck', 'prof. franz stuck', 'professor franz stuck',
#         'professor franz von stuck', 'franz v. stuck', 'von stuck'],
#        dtype=object),
#  None,
#  None,
#  array(['John Rea Neill', 'John Neill', 'J.R. Neill'], dtype=object),
#  array(["Moisei Isai'evich Sheinfinkel'"], dtype=object),
#  array(['Tane Matsukata'], dtype=object),
#  None,
#  array(['Brian Edward Benben'], dtype=object),
#  None,
#  None,
#  array(['Shinji Somai', 'Shinji Soumai'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Eugen Roth'], dtype=object),
#  None,
#  array(['Juli Sanchez'], dtype=object),
#  array(['Lozano', 'Fernando de Buen Lozano'], dtype=object),
#  None,
#  array(['Frank Kurt Zander', 'Frank Adolf Zander',
#         'Frank Kurt Adolf Zander'], dtype=object),
#  None,
#  array(['Rudolph Hans Albert Moshammer', 'Mosi'], dtype=object),
#  array(['Violant Lluïsa de Savoia'], dtype=object),
#  None,
#  None,
#  array(['Adelida', 'Adeliza de Normandie'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Robert Wilke', 'Bob Wilkie'], dtype=object),
#  None,
#  array(['Dustin Eli Whiteside'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['Bernard Stanley Bilk'], dtype=object),
#  array(['John Griffith Chaney', 'John Griffith "Jack" London',
#         'John Griffith Chaney London',
#         'John Griffith "Jack London" Chaney'], dtype=object),
#  array(['Mario Gómez García'], dtype=object),
#  None,
#  array(['Silje Margaretha Solberg'], dtype=object),
#  None,
#  array(['Behramji Merwanji Malabari'], dtype=object),
#  None,
#  array(['Anouk Teeuwe'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['Kim Won-ju', 'Il-yeop', 'Iryeop'], dtype=object),
#  None,
#  array(['Henriëtte Adriana Blok'], dtype=object),
#  None,
#  None,
#  array(['Melissa Marie Benoist'], dtype=object),
#  array(['Publius Licinius Valerianus', 'Valerianus'], dtype=object),
#  None,
#  array(['Severus II'], dtype=object),
#  array(['Hooke'], dtype=object),
#  array(['Flavius Valentinianus Iunior', 'Valentinianus II'], dtype=object),
#  array(['Ieoh Ming Pei', 'Yuming Bei', 'Yü-Ming Pei', 'Bèi Yù Míng',
#         'Bei Yu Ming', 'IM Pei', 'I.M. Pei'], dtype=object),
#  None,
#  array(['Kemal Tunçeri'], dtype=object),
#  array(['David Fedorovich Oistrakh'], dtype=object),
#  array(['Kike', 'Enrique Miguel Iglesias Preysler', 'Enrique M. Iglesias'],
#        dtype=object),
#  array(['Pope Sylvester I', 'Sylvester', 'Silvester I', 'Saint Sylvester',
#         'St. Sylvester', 'St Sylvester', 'Papa Silvester / Sylvester I'],
#        dtype=object),
#  None,
#  array(['Erlangga'], dtype=object),
#  None,
#  None,
#  array(['Miss Angela', 'Savannah', 'Black Lotus'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  array(['Victor Valdes'], dtype=object),
#  array(['Ivo Andric', 'ivo andric'], dtype=object),
#  None,
#  array(['Catherine Zeta-Jones Douglas'], dtype=object),
#  None,
#  array(['Mayangsari'], dtype=object),
#  None,
#  array(['Garça'], dtype=object),
#  array(['Shahriar Sadigh Afshar'], dtype=object),
#  None,
#  None,
#  array(['Haeckel', 'Ernst Heinrich Philipp August Haeckel',
#         'Ernst Heinrich Haeckel'], dtype=object),
#  array(['Marianne Evelyn Gabriel Faithfull'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['Cosimo the Elder', 'Cosimo Pater Patriae',
#         "Cosimo de' Medici the Elder", "Cosimo il Vecchio de' Medici",
#         "Cosimo de' Medici il Vecchio", "Cosimo di Giovanni de' Medici"],
#        dtype=object),
#  None,
#  None,
#  array(['Zenta Maurina'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  array(['Lev Šzeptycki', 'Leo Sheptycki', 'Leon Ludwik Szeptycki'],
#        dtype=object),
#  array(['Francisco Javier de Elio'], dtype=object),
#  None,
#  array(['Rolando'], dtype=object),
#  array(['Harald Meldal Eia', 'Hans Ruben Velsand', 'Rubenmann'],
#        dtype=object),
#  None,
#  None,
#  array(['Big Shell', 'Ifeanyi Festus Ezeli-Ndulue'], dtype=object),
#  array(['Lodovico Ariost', 'Lodovico Ariosto', 'Ariosto'], dtype=object),
#  array(['Karl Wernicke'], dtype=object),
#  array(['Richard L Synge', 'Richard L. M. Synge', 'Richard L M Synge',
#         'Richard LM Synge', 'Richard L. Synge', 'R. L. M. Synge',
#         'R L M Synge', 'RLM Synge', 'R. Synge', 'R Synge', 'Synge',
#         'Synge R', 'Synge R.', 'Synge R. L.', 'Synge RL', 'Synge R. L. M.',
#         'Synge RLM'], dtype=object),
#  array(['Randal Edward "Randy" Brecker'], dtype=object),
#  None,
#  array(['Isaac Babel', 'Isaak Emmanuilovich Babel'], dtype=object),
#  array(['James Danforth Quayle', 'James Danforth "Dan" Quayle',
#         'J. Danforth Quayle'], dtype=object),
#  array(['Walter Frederick Mondale'], dtype=object),
#  array(['Lisa Marie Nowak', 'Lisa Caputo'], dtype=object),
#  array(['Dorothée Pullinger Martin', 'Dorothee Aurelie Marianne Pullinger',
#         'Dorothee Pullinger', 'Dorothee Pullinger Martin'], dtype=object),
#  None,
#  array(['James B. Conant'], dtype=object),
#  None,
#  None,
#  array(['Robert Georges Nivelle'], dtype=object),
#  array(['Michailas Čechovas'], dtype=object),
#  None,
#  array(['Dr. James Rhyne Killian, Jr.', 'James R. Killian, Jr.'],
#        dtype=object),
#  array(['Suzy Durupt', 'Sunsiare of Larcone'], dtype=object),
#  None,
#  None,
#  array(['Victor, Baron Horta', 'Victor Horta baron', 'Victor, baron Horta',
#         'Victor Pierre Horta', 'Victor Pierre Baron Horta'], dtype=object),
#  None,
#  array(['François-René, vicomte de Chateaubriand',
#         'François-Auguste-René, vicomte de Chateaubriand',
#         'François-René, Vicomte de Chateaubriand',
#         'vicomte de Chateaubriand François-René',
#         'F. A. von Chateaubriand'], dtype=object),
#  None,
#  None,
#  None,
#  array(['Robert Levin'], dtype=object),
#  array(['Cicciolina', 'Elena Anna Staller', 'La Cicciolina'], dtype=object),
#  None,
#  None,
#  array(['Mieko Matsuki', 'Mieko Matuki', 'Miyuyu', 'Maturai-san',
#         'Matsurai-san', 'Matsuki Miyu'], dtype=object),
#  array(['Kotobuki Minako'], dtype=object),
#  None,
#  None,
#  array(['Couperin'], dtype=object),
#  array(['Susan Elizabeth Rice'], dtype=object),
#  None,
#  None,
#  array(['Stanard Ridgway'], dtype=object),
#  array(['Anson Maria Elizabeth Chan Fang On-sang', 'Chen Fang Ansheng',
#         'Fang Ansheng'], dtype=object),
#  array(['Zita of Bourbon Parma', 'Servant of God Zita of Austria-Hungary'],
#        dtype=object),
#  array(['Jerry John Rawlings'], dtype=object),
#  array(['Yi Wu'], dtype=object),
#  array(['Istvan Gulyas'], dtype=object),
#  array(['Esther Klein Szekeres'], dtype=object),
#  array(['Bernard William Jewry', 'Shane Fenton'], dtype=object),
#  array(['Piotr Stanislavovitch Koupinskyi'], dtype=object),
#  None,
#  array(['George Cooper Stevens', 'Jack Stevens'], dtype=object),
#  array(['Alan Jay Pakula', 'Alan Pakula'], dtype=object),
#  array(['Gustav Maria Leonhardt'], dtype=object),
#  array(['Joscelin', 'Joscelin I of Edessa',
#         'Joscelin I de Courtenay, Count of Edessa'], dtype=object),
#  None,
#  array(['Elias Boudinot Jr.', 'Elias Boudinot IV'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  array(['Elmer Verner McCollum'], dtype=object),
#  None,
#  None,
#  None,
#  None,
#  ...]

# %% [markdown]
# #### Extracting quotes with 'republicans' and 'democrats'

# %%
list1 = ['republican', 'republicans', 'democrat', 'democrats']
rep_dem_quotes = df[df["quotation"].str.contains('|'.join(list1))]
rep_dem_quotes
# Out:
#                   quoteID                                          quotation  \
# 849     2019-11-28-023610  I just hope the radicals in the democratic cam...
# 2145    2019-02-18-038200  inassimilable to democratic mores, in ways ver...
# 2221    2019-04-24-054807  The very idea of a Jewish state [ in Palestine...
# 2536    2019-11-10-046640  The ugly partisanship that is dominating our d...
# 2844    2019-07-10-075859  the same disillusionment, one where high-minde...
# ...                   ...                                                ...
# 203333  2019-02-07-067831  Most Americans are obviously not up on the dis...
# 203455  2019-01-10-085559  the most democratic province of the republic o...
# 203532  2019-08-08-039032  If a country's ruler were empowered to choose ...
# 206556  2019-01-28-112481  would have produced a more democratic sharing ...
# 207177  2019-03-14-008239  As a convinced anti-fascist, I apologize to al...
#
#                  speaker                 date  numOccurrences phase  \
# 849      Leung Chun-ying  2019-11-28 12:36:55               3     E
# 2145      Charles Taylor  2019-02-18 14:26:00               2     E
# 2221       Joseph Levine  2019-04-24 18:09:02               2     E
# 2536                None  2019-11-10 16:19:32               3     E
# 2844     Elliot Ackerman  2019-07-10 22:15:36               1     E
# ...                  ...                  ...             ...   ...
# 203333     Michael Kazin  2019-02-07 01:14:33               1     E
# 203455      William Dean  2019-01-10 21:00:03               1     E
# 203532              None  2019-08-08 02:36:19               3     E
# 206556  Lawrence Goodwyn  2019-01-28 17:26:59               3     E
# 207177    Antonio Tajani  2019-03-14 15:45:34               1     E
#
#        Transformers_score NLTK_score
# 849
# 2145
# 2221
# 2536
# 2844
# ...                   ...        ...
# 203333
# 203455
# 203532
# 206556
# 207177
#
# [314 rows x 8 columns]

# %%
congress_members_list = a.tolist()
congress_members_list
list1 = ['republican', 'republicans', 'democrat', 'democrats']
rep_dem_quotes = df[df["quotation"].str.contains('|'.join(list1 + congress_members_list))]
rep_dem_quotes
# Out:
# C:\Users\rened\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                   quoteID                                          quotation  \
# 115     2019-10-24-130308  You say, `Listen, I've been working on this --...
# 382     2019-12-27-026804  It appears that the defendant Netanyahu, who i...
# 422     2019-12-13-064494                      Practicing the King's Economy
# 676     2019-05-17-050756     Israel's most right-wing government in history
# 849     2019-11-28-023610  I just hope the radicals in the democratic cam...
# ...                   ...                                                ...
# 206941  2019-03-28-096758  The Washington view of Israel-Palestine is sti...
# 207037  2019-09-15-050649  waiting to hear from the Kingdom as to who the...
# 207142  2019-03-24-049069  This legislation appears designed less to comb...
# 207177  2019-03-14-008239  As a convinced anti-fascist, I apologize to al...
# 207445  2019-10-11-074429                      proud Jew and lover of Israel
#
#                        speaker                 date  numOccurrences phase  \
# 115                  Al Pacino  2019-10-24 09:00:16               1     E
# 382                Benny Gantz  2019-12-27 00:00:00              23     E
# 422                       None  2019-12-13 16:50:17               3     E
# 676                       None  2019-05-17 23:27:20               4     E
# 849            Leung Chun-ying  2019-11-28 12:36:55               3     E
# ...                        ...                  ...             ...   ...
# 206941              Ben Rhodes  2019-03-28 09:00:04               5     E
# 207037  President Donald Trump  2019-09-15 20:20:06              32     E
# 207142          Jeremy Ben-Ami  2019-03-24 21:13:07              10     E
# 207177          Antonio Tajani  2019-03-14 15:45:34               1     E
# 207445           Hillel Halkin  2019-10-11 09:00:00               1     E
#
#        Transformers_score NLTK_score
# 115
# 382
# 422
# 676
# 849
# ...                   ...        ...
# 206941
# 207037
# 207142
# 207177
# 207445
#
# [1151 rows x 8 columns]

# %% [markdown]
# ### 6. Sentiment Analysis

# %% [markdown]
# #### 1. Transformers library (DistilBERT architecture)

# %%
from transformers import pipeline
classifier = pipeline('sentiment-analysis')

# %%
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2019-04-17-024782                It is not a low-income immigration,
# 1  2019-04-02-001128  a champion figure skater switching to roller s...
# 2  2019-05-09-055187  It makes it much more difficult for him to mak...
# 3  2019-10-31-056366                       It puts me in a predicament,
# 4  2019-01-04-001792                                  A Pile of Leaves.
#
#           speaker                 date  numOccurrences phase
# 0    James Fisher  2019-04-17 13:31:18               1     E
# 1     John Updike  2019-04-02 14:58:33               2     E
# 2            None  2019-05-09 18:11:29               1     E
# 3  Xavier Becerra  2019-10-31 16:45:15               3     E
# 4            None  2019-01-04 10:00:07               1     E

# %%
print(df["quotation"][1])
classifier(df["quotation"][1])
# Out:
# a champion figure skater switching to roller skates.
# [{'label': 'POSITIVE', 'score': 0.9995531439781189}]

# %%
df["Transformers_score"] = ""
for i in range(100):
    df["Transformers_score"][i] = classifier(df["quotation"][i])
df.head()
# Out:
# C:\Users\rened\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              quoteID                                          quotation  \
# 0  2019-04-17-024782                It is not a low-income immigration,
# 1  2019-04-02-001128  a champion figure skater switching to roller s...
# 2  2019-05-09-055187  It makes it much more difficult for him to mak...
# 3  2019-10-31-056366                       It puts me in a predicament,
# 4  2019-01-04-001792                                  A Pile of Leaves.
#
#           speaker                 date  numOccurrences phase  \
# 0    James Fisher  2019-04-17 13:31:18               1     E
# 1     John Updike  2019-04-02 14:58:33               2     E
# 2            None  2019-05-09 18:11:29               1     E
# 3  Xavier Becerra  2019-10-31 16:45:15               3     E
# 4            None  2019-01-04 10:00:07               1     E
#
#                                   Transformers_score
# 0  [{'label': 'POSITIVE', 'score': 0.991260886192...
# 1  [{'label': 'POSITIVE', 'score': 0.999553143978...
# 2  [{'label': 'NEGATIVE', 'score': 0.999620079994...
# 3  [{'label': 'NEGATIVE', 'score': 0.982650339603...
# 4  [{'label': 'NEGATIVE', 'score': 0.999175965785...

# %% [markdown]
# #### 2. NLTK

# %%
# https://realpython.com/python-nltk-sentiment-analysis/
# pip install nltk
import nltk

# nltk.download()
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\rened\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
sia.polarity_scores(df["quotation"][1])
# Out:
# {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.5994}

# %%
df["NLTK_score"] = ""
for i in range(100):
    df["NLTK_score"][i] = sia.polarity_scores(df["quotation"][i])
df.head()
# Out:
# C:\Users\rened\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              quoteID                                          quotation  \
# 0  2019-04-17-024782                It is not a low-income immigration,
# 1  2019-04-02-001128  a champion figure skater switching to roller s...
# 2  2019-05-09-055187  It makes it much more difficult for him to mak...
# 3  2019-10-31-056366                       It puts me in a predicament,
# 4  2019-01-04-001792                                  A Pile of Leaves.
#
#           speaker                 date  numOccurrences phase  \
# 0    James Fisher  2019-04-17 13:31:18               1     E
# 1     John Updike  2019-04-02 14:58:33               2     E
# 2            None  2019-05-09 18:11:29               1     E
# 3  Xavier Becerra  2019-10-31 16:45:15               3     E
# 4            None  2019-01-04 10:00:07               1     E
#
#                                   Transformers_score  \
# 0  [{'label': 'POSITIVE', 'score': 0.991260886192...
# 1  [{'label': 'POSITIVE', 'score': 0.999553143978...
# 2  [{'label': 'NEGATIVE', 'score': 0.999620079994...
# 3  [{'label': 'NEGATIVE', 'score': 0.982650339603...
# 4  [{'label': 'NEGATIVE', 'score': 0.999175965785...
#
#                                           NLTK_score
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'comp...
# 2  {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...

# %% [markdown]
# #### 3. SpaCy

# %%
# pip install spacy
# pip install pip install spacytextblob==0.1.7
# !python -m spacy download en_core_web_sm

import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe("spacytextblob")
nlp(df["quotation"][1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-f91ad6668835> in <module>
#       7
#       8 nlp = spacy.load('en_core_web_sm')
# ----> 9 nlp.add_pipe(source='spacytextblob')
#      10 nlp(df["quotation"][1])
#
# TypeError: add_pipe() got an unexpected keyword argument 'source'

# %% [markdown]
# #### Textblob library
#
# It's using a classical bag of words approach so too simple for us.

# %%
from textblob import TextBlob
TextBlob(df["quotation"][5]).sentiment
# Out:
# Sentiment(polarity=0.6, subjectivity=1.0)
